# %% [markdown]
# Notebook used to compute input HCQTs and targets for every track for different task types
#
# In each cell we manually run a script with the given parameters

# %%
cd ../deepsalience
# Out:
# /scratch/rmb456/multif0/deepsalience

# %%
# import medleydb as mdb
# import numpy as np
# import os


# mel1_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/"
# mel2_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/"
# mel3_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/"
# mf0_incomplete = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/"
# mf0_complete = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/"

# mtracks = mdb.load_all_multitracks(
#     dataset_version=['V1', 'V2', 'EXTRA']
# )

# for mtrack in mtracks:
# #     print(mtrack.track_id)
#     fpath = os.path.join(mel1_dir, 'inputs', '{}_mel1_input.npy'.format(mtrack.track_id))
#     if not os.path.exists(fpath):
# #         print("   > no npy file")
#         continue

#     data = np.load(fpath, mmap_mode='r')

#     if data.shape[0] != 6:
#         print(mtrack.track_id)
#         print("   > {}".format(data.shape))
#         os.remove(fpath)
#         os.remove(os.path.join(mel2_dir, 'inputs', '{}_mel2_input.npy'.format(mtrack.track_id)))
#         os.remove(os.path.join(mel3_dir, 'inputs', '{}_mel3_input.npy'.format(mtrack.track_id)))
#         os.remove(os.path.join(mf0_incomplete, 'inputs', '{}_multif0_incomplete_input.npy'.format(mtrack.track_id)))

# %%
# %run compute_training_data.py --help

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/" "solo_pitch" -1 "" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/" "melody1" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs/" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/" "multif0_complete" -1 '' "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/" "melody2" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs/" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/" "melody3" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/" "multif0_incomplete" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/" "bass" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/inputs" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/" "vocal" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/inputs" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
#     > AClassicEducation_NightOwl already done!
# AimeeNorwich_Child
#     > AimeeNorwich_Child already done!
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
#     AimeeNorwich_Flying No vocal data
#     > AlexanderRoss_GoodbyeBolero already done!
# AlexanderRoss_VelvetCurtain
#     > AlexanderRoss_VelvetCurtain already done!
# AmarLal_Rest
#     AmarLal_Rest No vocal data
# AmarLal_SpringDay1
#     AmarLal_SpringDay1 No vocal data
# Auctioneer_OurFutureFaces
#     > skipping stem 3 of ['vocalists'] in Auctioneer_OurFutureFaces
#     > skipping stem 3 of ['vocalists'] in Auctioneer_OurFutureFaces
# BigTroubles_Phantom
# AvaLuna_Waterduct
#     > skipping stem 3 of ['vocalists'] in AvaLuna_Waterduct
#     > skipping stem 3 of ['vocalists'] in AvaLuna_Waterduct
#     > BigTroubles_Phantom already done!
# BrandonWebster_DontHearAThing
#     > skipping stem 1 of ['male speaker'] in BrandonWebster_DontHearAThing
#     > skipping stem 1 of ['male speaker'] in BrandonWebster_DontHearAThing
# BrandonWebster_YesSirICanFly
#     > BrandonWebster_YesSirICanFly already done!
# CelestialShore_DieForUs
#     > CelestialShore_DieForUs already done!
# ChrisJacoby_BoothShotLincoln
#     ChrisJacoby_BoothShotLincoln No vocal data
# ChrisJacoby_PigsFoot
#     ChrisJacoby_PigsFoot No vocal data
# ClaraBerryAndWooldog_AirTraffic
#     > ClaraBerryAndWooldog_AirTraffic already done!
# ClaraBerryAndWooldog_Boys
#     > ClaraBerryAndWooldog_Boys already done!
# ClaraBerryAndWooldog_Stella
#     > ClaraBerryAndWooldog_Stella already done!
# ClaraBerryAndWooldog_TheBadGuys
#     > ClaraBerryAndWooldog_TheBadGuys already done!
# ClaraBerryAndWooldog_WaltzForMyVictims
#     > ClaraBerryAndWooldog_WaltzForMyVictims already done!
# Creepoid_OldTree
#     > Creepoid_OldTree already done!
# CroqueMadame_Oil
#     CroqueMadame_Oil No vocal data
# CroqueMadame_Pilot
#     CroqueMadame_Pilot No vocal data
# Debussy_LenfantProdigue
#     > Debussy_LenfantProdigue already done!
# DreamersOfTheGhetto_HeavyLove
#     > skipping stem 2 of ['vocalists'] in DreamersOfTheGhetto_HeavyLove
#     > skipping stem 2 of ['vocalists'] in DreamersOfTheGhetto_HeavyLove
#     > skipping stem 2 of ['vocalists'] in DreamersOfTheGhetto_HeavyLove
# EthanHein_1930sSynthAndUprightBass
#     EthanHein_1930sSynthAndUprightBass No vocal data
# EthanHein_BluesForNofi
#     EthanHein_BluesForNofi No vocal data
# EthanHein_GirlOnABridge
#     EthanHein_GirlOnABridge No vocal data
# EthanHein_HarmonicaFigure
#     EthanHein_HarmonicaFigure No vocal data
# FacesOnFilm_WaitingForGa
#     > FacesOnFilm_WaitingForGa already done!
# FamilyBand_Again
#     > skipping stem 2 of ['vocalists'] in FamilyBand_Again
#     > skipping stem 2 of ['vocalists'] in FamilyBand_Again
# Grants_PunchDrunk
#     > Grants_PunchDrunk already done!
# Handel_TornamiAVagheggiar
#     > Handel_TornamiAVagheggiar already done!
# HeladoNegro_MitadDelMundo
#     > HeladoNegro_MitadDelMundo already done!
# HezekiahJones_BorrowedHeart
#     > HezekiahJones_BorrowedHeart already done!
# HopAlong_SisterCities
#     > skipping stem 3 of ['vocalists'] in HopAlong_SisterCities
#     > skipping stem 3 of ['vocalists'] in HopAlong_SisterCities
# InvisibleFamiliars_DisturbingWildlife
#     > skipping stem 7 of ['vocalists'] in InvisibleFamiliars_DisturbingWildlife
#     > skipping stem 7 of ['vocalists'] in InvisibleFamiliars_DisturbingWildlife
#     > skipping stem 7 of ['vocalists'] in InvisibleFamiliars_DisturbingWildlife
# JoelHelander_Definition
#     JoelHelander_Definition No vocal data
# JoelHelander_ExcessiveResistancetoChange
#     JoelHelander_ExcessiveResistancetoChange No vocal data
# JoelHelander_IntheAtticBedroom
#     JoelHelander_IntheAtticBedroom No vocal data
# KarimDouaidy_Hopscotch
#     KarimDouaidy_Hopscotch No vocal data
# KarimDouaidy_Yatora
#     KarimDouaidy_Yatora No vocal data
# LizNelson_Coldwar
#     > LizNelson_Coldwar already done!
# LizNelson_ImComingHome
#     > LizNelson_ImComingHome already done!
#     > LizNelson_Rainfall already done!
# LizNelson_Rainfall
# Lushlife_ToynbeeSuite
#     > Lushlife_ToynbeeSuite already done!
# MatthewEntwistle_AnEveningWithOliver
#     > skipping stem 6 of ['vocalists'] in MatthewEntwistle_AnEveningWithOliver
# MatthewEntwistle_DontYouEver
#     > MatthewEntwistle_DontYouEver already done!
# MatthewEntwistle_FairerHopes
#     MatthewEntwistle_FairerHopes No vocal data
# MatthewEntwistle_ImpressionsOfSaturn
#     MatthewEntwistle_ImpressionsOfSaturn No vocal data
# MatthewEntwistle_Lontano
#     > MatthewEntwistle_Lontano already done!
# MatthewEntwistle_TheArch
#     MatthewEntwistle_TheArch No vocal data
# MatthewEntwistle_TheFlaxenField
#     MatthewEntwistle_TheFlaxenField No vocal data
# Meaxic_TakeAStep
#     > Meaxic_TakeAStep already done!
# Meaxic_YouListen
#     > Meaxic_YouListen already done!
# MichaelKropf_AllGoodThings
#     MichaelKropf_AllGoodThings No vocal data
# Mozart_BesterJungling
#     > Mozart_BesterJungling already done!
# Mozart_DiesBildnis
#     > Mozart_DiesBildnis already done!
# MusicDelta_80sRock
#     > MusicDelta_80sRock already done!
# MusicDelta_Beatles
#     > MusicDelta_Beatles already done!
# MusicDelta_BebopJazz
#     MusicDelta_ChineseXinJing No vocal data
#     MusicDelta_BebopJazz No vocal data
# MusicDelta_Beethoven
#     MusicDelta_Beethoven No vocal data
# MusicDelta_Britpop
#     > MusicDelta_Britpop already done!
# MusicDelta_ChineseChaoZhou
#     MusicDelta_ChineseChaoZhou No vocal data
# MusicDelta_ChineseDrama
#     MusicDelta_ChineseDrama No vocal data
# MusicDelta_ChineseHenan
#     MusicDelta_ChineseHenan No vocal data
# MusicDelta_ChineseJiangNan
#     MusicDelta_ChineseJiangNan No vocal data
# MusicDelta_ChineseXinJing
# MusicDelta_ChineseYaoZu
#     MusicDelta_ChineseYaoZu No vocal data
# MusicDelta_CoolJazz
#     MusicDelta_CoolJazz No vocal data
# MusicDelta_Country1
#     > MusicDelta_Country1 already done!
# MusicDelta_Disco
# MusicDelta_Country2
#     > MusicDelta_Country2 already done!
#     > MusicDelta_Disco already done!
# MusicDelta_FreeJazz
#     MusicDelta_FreeJazz No vocal data
#     MusicDelta_FunkJazz No vocal data
# MusicDelta_FunkJazz
# MusicDelta_FusionJazz
#     MusicDelta_FusionJazz No vocal data
# MusicDelta_Gospel
#     > MusicDelta_Gospel already done!
# MusicDelta_GriegTrolltog
#     MusicDelta_GriegTrolltog No vocal data
# MusicDelta_Grunge
#     > MusicDelta_Grunge already done!
# MusicDelta_Hendrix
#     > MusicDelta_Hendrix already done!
# MusicDelta_InTheHalloftheMountainKing
#     MusicDelta_InTheHalloftheMountainKing No vocal data
# MusicDelta_LatinJazz
#     MusicDelta_LatinJazz No vocal data
# MusicDelta_ModalJazz
# MusicDelta_Punk
#     MusicDelta_ModalJazz No vocal data
# MusicDelta_Pachelbel
#     MusicDelta_Pachelbel No vocal data
#     > MusicDelta_Punk already done!
# MusicDelta_Reggae
#     > MusicDelta_Reggae already done!
# MusicDelta_Rock
#     > MusicDelta_Rock already done!
# MusicDelta_Rockabilly
#     > MusicDelta_Rockabilly already done!
# MusicDelta_Shadows
#     MusicDelta_Shadows No vocal data
# MusicDelta_SpeedMetal
#     MusicDelta_SpeedMetal No vocal data
# MusicDelta_SwingJazz
#     MusicDelta_SwingJazz No vocal data
# MusicDelta_Vivaldi
#     MusicDelta_Vivaldi No vocal data
# MusicDelta_Zeppelin
#     MusicDelta_Zeppelin No vocal data
# NightPanther_Fire
#     > skipping stem 2 of ['vocalists'] in NightPanther_Fire
#     > skipping stem 2 of ['vocalists'] in NightPanther_Fire
#     > skipping stem 2 of ['vocalists'] in NightPanther_Fire
# Phoenix_BrokenPledgeChicagoReel
#     Phoenix_BrokenPledgeChicagoReel No vocal data
# Phoenix_ColliersDaughter
#     Phoenix_ColliersDaughter No vocal data
# Phoenix_ElzicsFarewell
#     Phoenix_ElzicsFarewell No vocal data
# Phoenix_LarkOnTheStrandDrummondCastle
#     Phoenix_LarkOnTheStrandDrummondCastle No vocal data
# Phoenix_ScotchMorris
#     Phoenix_ScotchMorris No vocal data
#     Phoenix_SeanCaughlinsTheScartaglen No vocal data
# Phoenix_SeanCaughlinsTheScartaglen
# PortStWillow_StayEven
#     > skipping stem 1 of ['vocalists'] in PortStWillow_StayEven
#     > skipping stem 1 of ['vocalists'] in PortStWillow_StayEven
# PurlingHiss_Lolita
#     > PurlingHiss_Lolita already done!
# Schubert_Erstarrung
# Schumann_Mignon
#     > Schubert_Erstarrung already done!
#     > Schumann_Mignon already done!
# SecretMountains_HighHorse
#     > skipping stem 2 of ['vocalists'] in SecretMountains_HighHorse
#     > skipping stem 2 of ['vocalists'] in SecretMountains_HighHorse
# Snowmine_Curfews
#     > Snowmine_Curfews already done!
# StevenClark_Bounty
#     > skipping stem 3 of ['vocalists'] in StevenClark_Bounty
#     > skipping stem 3 of ['vocalists'] in StevenClark_Bounty
#     > skipping stem 3 of ['vocalists'] in StevenClark_Bounty
# StrandOfOaks_Spacestation
#     > skipping stem 2 of ['vocalists'] in StrandOfOaks_Spacestation
#     > skipping stem 2 of ['vocalists'] in StrandOfOaks_Spacestation
# SweetLights_YouLetMeDown
#     > SweetLights_YouLetMeDown already done!
# TablaBreakbeatScience_Animoog
#     TablaBreakbeatScience_Animoog No vocal data
#     TablaBreakbeatScience_Scorpio No vocal data
# TablaBreakbeatScience_CaptainSky
#     TablaBreakbeatScience_CaptainSky No vocal data
# TablaBreakbeatScience_MiloVsMongo
#     TablaBreakbeatScience_MiloVsMongo No vocal data
# TablaBreakbeatScience_MoodyPlucks
#     TablaBreakbeatScience_MoodyPlucks No vocal data
# TablaBreakbeatScience_PhaseTransition
#     TablaBreakbeatScience_PhaseTransition No vocal data
# TablaBreakbeatScience_RockSteady
#     TablaBreakbeatScience_RockSteady No vocal data
# TablaBreakbeatScience_Scorpio
# TablaBreakbeatScience_Vger
#     TablaBreakbeatScience_Vger No vocal data
# TablaBreakbeatScience_WhoIsIt
#     TablaBreakbeatScience_WhoIsIt No vocal data
# TheDistricts_Vermont
#     > skipping stem 2 of ['vocalists'] in TheDistricts_Vermont
#     > skipping stem 2 of ['vocalists'] in TheDistricts_Vermont
# TheScarletBrand_LesFleursDuMal
#     > TheScarletBrand_LesFleursDuMal already done!
# TheSoSoGlos_Emergency
#     > skipping stem 2 of ['vocalists'] in TheSoSoGlos_Emergency
#     > skipping stem 2 of ['vocalists'] in TheSoSoGlos_Emergency
#     > Wolf_DieBekherte already done!
# Wolf_DieBekherte
# Allegria_MendelssohnMovement1
#     Allegria_MendelssohnMovement1 No vocal data
# AmadeusRedux_MozartAllegro
#     AmadeusRedux_MozartAllegro No vocal data
# AmadeusRedux_SchubertMovement2
#     AmadeusRedux_SchubertMovement2 No vocal data
# AmadeusRedux_SchubertMovement3
#     AmadeusRedux_SchubertMovement3 No vocal data
# BarefootSisters_RedJetta
#     > skipping stem 1 of ['vocalists'] in BarefootSisters_RedJetta
# CassandraJenkins_PerfectDay
#     > CassandraJenkins_PerfectDay already done!
# CatMartino_IPromise
#     > CatMartino_IPromise already done!
# Cayetana_MissThing
#     > Cayetana_MissThing already done!
# DahkaBand_SoldierMan
#     > skipping stem 3 of ['male singer'] in DahkaBand_SoldierMan
# DeadMilkmen_PrisonersCinema
#     > DeadMilkmen_PrisonersCinema already done!
# DeclareAString_MendelssohnPianoTrio1Movement1
#     DeclareAString_MendelssohnPianoTrio1Movement1 No vocal data
# DeclareAString_MendelssohnPianoTrio1Movement2
#     DeclareAString_MendelssohnPianoTrio1Movement2 No vocal data
# FallingSparks_Improvisation1
#     FallingSparks_Improvisation2 No vocal data
#     FallingSparks_Improvisation1 No vocal data
# FallingSparks_Improvisation2
# FallingSparks_Improvisation3
#     FallingSparks_Improvisation3 No vocal data
# FallingSparks_PakKlongTalad
#     FallingSparks_PakKlongTalad No vocal data
# FennelCartwright_DearTessie
#     FennelCartwright_DearTessie No vocal data
# FennelCartwright_FlowerDrumSong
#     FennelCartwright_FlowerDrumSong No vocal data
# FennelCartwright_WinterLake
#     FennelCartwright_WinterLake No vocal data
# FilthyBird_IdLikeToKnow
#     > FilthyBird_IdLikeToKnow already done!
# FruitCathedral_KeepMeRunnin
# HopsNVinyl_ChickenFriedSteak
#     > skipping stem 4 of ['vocalists'] in FruitCathedral_KeepMeRunnin
#     HopsNVinyl_ChickenFriedSteak No vocal data
# HopsNVinyl_HoneyBrown
#     HopsNVinyl_HoneyBrown No vocal data
# HopsNVinyl_ReignCheck
#     HopsNVinyl_ReignCheck No vocal data
# HopsNVinyl_WidowsWalk
#     HopsNVinyl_WidowsWalk No vocal data
# Karachacha_Volamos
#     Karachacha_Volamos No vocal data
# Katzn_CharlieKnox
#     Katzn_CharlieKnox No vocal data
# LewisAndClarke_TheSilverSea
#     > skipping stem 1 of ['male singer'] in LewisAndClarke_TheSilverSea
#     > skipping stem 1 of ['male singer'] in LewisAndClarke_TheSilverSea
# LittleTybee_TheAlchemist
#     > LittleTybee_TheAlchemist already done!
# MatthewEntwistle_ReturnToVenezia
#     MatthewEntwistle_ReturnToVenezia No vocal data
# MidnightBlue_HuntingSeason
#     > MidnightBlue_HuntingSeason already done!
# MidnightBlue_StarsAreScreaming
#     > MidnightBlue_StarsAreScreaming already done!
# MutualBenefit_NotForNothing
#     > MutualBenefit_NotForNothing already done!
# PatternIsMovement_SaveMe
#     > PatternIsMovement_SaveMe already done!
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#     > skipping stem 5 of ['vocalists'] in PeterMatthewBauer_YouAlwaysLookForSomeoneLost
# Plasma_GoodShout
#     Plasma_GoodShout No vocal data
# PoliceHearingDepartment_Brahms
#     PoliceHearingDepartment_Brahms No vocal data
# PoliceHearingDepartment_SchumannMovement1
#     PoliceHearingDepartment_SchumannMovement1 No vocal data
# PoliceHearingDepartment_SchumannMovement2
#     PoliceHearingDepartment_SchumannMovement2 No vocal data
# PoliceHearingDepartment_VivaldiMovement1
#     PoliceHearingDepartment_VivaldiMovement1 No vocal data
# PoliceHearingDepartment_VivaldiMovement2
#     PoliceHearingDepartment_VivaldiMovement2 No vocal data
# PoliceHearingDepartment_VivaldiMovement3
#     PoliceHearingDepartment_VivaldiMovement3 No vocal data
# QuantumChromos_Circuits
#     > skipping stem 6 of ['male singer'] in QuantumChromos_Circuits
# RodrigoBonelli_BalladForLaura
#     RodrigoBonelli_BalladForLaura No vocal data
# SasquatchConnection_BoomBoxing
# SasquatchConnection_HolyClamsBatman
#     SasquatchConnection_BoomBoxing No vocal data
#     SasquatchConnection_HolyClamsBatman No vocal data
# SasquatchConnection_Illuminati
#     SasquatchConnection_Illuminati No vocal data
# SasquatchConnection_Struttin
#     SasquatchConnection_Struttin No vocal data
# SasquatchConnection_ThanksALatte
#     SasquatchConnection_ThanksALatte No vocal data
# SlowGhost_FirstSnow
#     SlowGhost_FirstSnow No vocal data
# SlowGhost_MidnightGroove
#     SlowGhost_MidnightGroove No vocal data
# SlowGhost_Peanut
#     SlowGhost_Peanut No vocal data
# SlowGhost_YoureAMystery
#     SlowGhost_YoureAMystery No vocal data
# SongYiJeon_TwoMoons
#     > skipping stem 1 of ['female singer'] in SongYiJeon_TwoMoons
# Sweat_AlmostAlways
#     Sweat_AlmostAlways No vocal data
# Sweat_Anecdoche
#     Sweat_Anecdoche No vocal data
# Sweat_Elegy
#     Sweat_Elegy No vocal data
# Sweat_Mesozoic
#     Sweat_Mesozoic No vocal data
# Sweat_Sn1572
#     Sweat_Sn1572 No vocal data
# Sweat_Tact
#     Sweat_Tact No vocal data
# TemperedElan_DorothyJeanne
#     TemperedElan_DorothyJeanne No vocal data
# TemperedElan_WiseOne
#     TemperedElan_WiseOne No vocal data
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
#     TheFranckDuo_FranckViolinSonataInAMajorMovement1 No vocal data
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
#     TheFranckDuo_FranckViolinSonataInAMajorMovement2 No vocal data
# TheKitchenettes_Alive
#     > skipping stem 1 of ['vocalists'] in TheKitchenettes_Alive
#     > skipping stem 1 of ['vocalists'] in TheKitchenettes_Alive
# TheNoHoStringOrchestra_ElgarMovement1
#     TheNoHoStringOrchestra_ElgarMovement1 No vocal data
# TheNoHoStringOrchestra_ElgarMovement2
#     TheNoHoStringOrchestra_ElgarMovement2 No vocal data
# TheNoHoStringOrchestra_ElgarMovement3
#     TheNoHoStringOrchestra_ElgarMovement3 No vocal data
# TheTonTons_Lush
#     > TheTonTons_Lush already done!
# TleilaxEnsemble_Late
#     > skipping stem 4 of ['male singer'] in TleilaxEnsemble_Late
#     > skipping stem 4 of ['male singer'] in TleilaxEnsemble_Late
# TleilaxEnsemble_MelancholyFlowers
#     > skipping stem 4 of ['male singer'] in TleilaxEnsemble_MelancholyFlowers
#     > Torres_NewSkin already done!
#     > skipping stem 4 of ['male singer'] in TleilaxEnsemble_MelancholyFlowers
# Torres_NewSkin
# TrevorAndTheSoundwaves_AloneAndSad
#     > TrevorAndTheSoundwaves_AloneAndSad already done!
# Verdi_IlTrovatore
#     > skipping stem 1 of ['female singer'] in Verdi_IlTrovatore
# AHa_TakeOnMe
#     > AHa_TakeOnMe already done!
# AcDc_BackInBlack
#     > AcDc_BackInBlack already done!
# Adele_SomeoneLikeYou
#     > Adele_SomeoneLikeYou already done!
# Aerosmith_LoveInAnElevator
#     > Aerosmith_LoveInAnElevator already done!
# AlanisMorissette_YouOughtaKnow
#     > using precomputed CQT for AlanisMorissette_YouOughtaKnow_MIX.wav
# Blink182_AllTheSmallThings
#     > Blink182_AllTheSmallThings already done!
# Blondie_OneWayOrAnother
#     > skipping stem 1 of ['vocalists'] in Blondie_OneWayOrAnother
#     > skipping stem 1 of ['vocalists'] in Blondie_OneWayOrAnother
# BlueOysterCult_DontFearTheReaper
#     > BlueOysterCult_DontFearTheReaper already done!
# BobSeger_OldTimeRockAndRoll
#     > using precomputed CQT for BobSeger_OldTimeRockAndRoll_MIX.wav
# Coldplay_InMyPlace
#     Coldplay_InMyPlace No vocal data
# Coldplay_Shiver
#     > Coldplay_Shiver already done!
# CorinneBaileyRae_PutYourRecordsOn
#     > using precomputed CQT for CorinneBaileyRae_PutYourRecordsOn_MIX.wav
# LaRoux_Bulletproof
#     > skipping stem 3 of ['vocalists'] in LaRoux_Bulletproof
#     > skipping stem 3 of ['vocalists'] in LaRoux_Bulletproof
# LadyGagaFeaturingBeyonce_Telephone
#     > skipping stem 6 of ['vocalists'] in LadyGagaFeaturingBeyonce_Telephone
#     > skipping stem 6 of ['vocalists'] in LadyGagaFeaturingBeyonce_Telephone
#     > skipping stem 6 of ['vocalists'] in LadyGagaFeaturingBeyonce_Telephone
#     > skipping stem 6 of ['vocalists'] in LadyGagaFeaturingBeyonce_Telephone
# LadyGaga_BadRomance
#     LadyGaga_BadRomance No vocal data
# LadyGaga_BornThisWay
#     > using precomputed CQT for LadyGaga_BornThisWay_MIX.wav
# MirandaCosgrove_HeadphonesOn
#     > using precomputed CQT for MirandaCosgrove_HeadphonesOn_MIX.wav
#     Saved data for MirandaCosgrove_HeadphonesOn_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# Misfits_AstroZombies
#     > using precomputed CQT for Misfits_AstroZombies_MIX.wav
#     Saved data for BobSeger_OldTimeRockAndRoll_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# Boston_MoreThanAFeeling
#     > using precomputed CQT for Boston_MoreThanAFeeling_MIX.wav
#     Saved data for CorinneBaileyRae_PutYourRecordsOn_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# CountZero_Shake
#     > using precomputed CQT for CountZero_Shake_MIX.wav
#     Saved data for AlanisMorissette_YouOughtaKnow_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# AllThatRemains_Chiron
#     AllThatRemains_Chiron No vocal data
# AnEndlessSporadic_Anything
#     AnEndlessSporadic_Anything No vocal data
# Anberlin_TheFeelGoodDrag
#     Anberlin_TheFeelGoodDrag No vocal data
# ArcadeFire_BlackMirror
#     > ArcadeFire_BlackMirror already done!
# ArcticMonkeys_Brainstorm
#     ArcticMonkeys_Brainstorm No vocal data
# BillyIdol_WhiteWedding
#     > BillyIdol_WhiteWedding already done!
# BillySquier_TheStroke
#     > BillySquier_TheStroke already done!
# BlackEyedPeas_IGottaFeeling
#     > skipping stem 10 of ['vocalists'] in BlackEyedPeas_IGottaFeeling
#     > skipping stem 10 of ['vocalists'] in BlackEyedPeas_IGottaFeeling
# BlackSabbath_WarPigs
#     > BlackSabbath_WarPigs already done!
# TheBlackKeys_YourTouch
#     > skipping stem 3 of ['male singer'] in TheBlackKeys_YourTouch
# TheBravery_Believe
#     > skipping stem 1 of ['vocalists'] in TheBravery_Believe
# TheBronx_FalseAlarm
#     TheBronx_FalseAlarm No vocal data
# TheBronx_SixDaysAWeek
#     TheBronx_SixDaysAWeek No vocal data
# TheKillers_SomebodyToldMe
#     > using precomputed CQT for TheKillers_SomebodyToldMe_MIX.wav
#     Saved data for LadyGaga_BornThisWay_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# LambOfGod_Requiem
#     > using precomputed CQT for LambOfGod_Requiem_MIX.wav
#     Saved data for Misfits_AstroZombies_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# ModestMouse_FloatOn
#     > using precomputed CQT for ModestMouse_FloatOn_MIX.wav
#     Saved data for TheKillers_SomebodyToldMe_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# TheKooks_Naive
#     > using precomputed CQT for TheKooks_Naive_MIX.wav
#     Saved data for CountZero_Shake_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# CountingCrows_AccidentallyInLove
#     > using precomputed CQT for CountingCrows_AccidentallyInLove_MIX.wav
#     Saved data for Boston_MoreThanAFeeling_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# BradPaisley_MudOnTheTires
#     > using precomputed CQT for BradPaisley_MudOnTheTires_MIX.wav
#     Saved data for ModestMouse_FloatOn_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# Muffs_KidsInAmerica
#     > using precomputed CQT for Muffs_KidsInAmerica_MIX.wav
#     Saved data for LambOfGod_Requiem_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# LennyKravitz_AreYouGonnaGoMyWay
#     > using precomputed CQT for LennyKravitz_AreYouGonnaGoMyWay_MIX.wav
#     Saved data for TheKooks_Naive_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# TheLastGoodnight_PicturesOfYou
#     > using precomputed CQT for TheLastGoodnight_PicturesOfYou_MIX.wav
#     Saved data for TheLastGoodnight_PicturesOfYou_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# TheTurtles_HappyTogether
#     > using precomputed CQT for TheTurtles_HappyTogether_MIX.wav
#     Saved data for CountingCrows_AccidentallyInLove_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# CrazyFrog_JingleBells
#     > skipping stem 3 of ['vocalists'] in CrazyFrog_JingleBells
# FleetwoodMac_Rhiannon
#     > FleetwoodMac_Rhiannon already done!
# FlightOfTheConcords_BusinessTime
#     > FlightOfTheConcords_BusinessTime already done!
# FooFighters_AllMyLife
#     > FooFighters_AllMyLife already done!
# Incubus_Drive
#     > using precomputed CQT for Incubus_Drive_MIX.wav
#     Saved data for BradPaisley_MudOnTheTires_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# BrooksDunn_HillbillyDeluxe
#     > using precomputed CQT for BrooksDunn_HillbillyDeluxe_MIX.wav
#     Saved data for Muffs_KidsInAmerica_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# Muse_Hysteria
#     > using precomputed CQT for Muse_Hysteria_MIX.wav
#     Saved data for LennyKravitz_AreYouGonnaGoMyWay_vocal to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/
# LilyAllen_NotFair
#     > using precomputed CQT for LilyAllen_NotFair_MIX.wav

# %%
data_dir = ("/scratch/rmb456/multif0_ismir2017/" +
    "training_data_with_blur/multif0_complete")

# %%
import medleydb as mdb
import glob
import shutil
import os

# %%
mtracks = list(mtracks)

# %%
new_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/bad_extras"

# %%
mtracks = mdb.load_all_multitracks(dataset_version=['EXTRA'])
good_count = 0
bad_count = 0

for mtrack in mtracks:
    bad_mtrack = False
    for stem in mtrack.stems.values():
        if stem.pitch_estimate_pyin is not None:

            if 'p' in stem.f0_type:
                bad_mtrack = True
                print(stem.instrument)
    if bad_mtrack:
        bad_count += 1
        print mtrack.track_id
    else:
        good_count += 1
        
        
    if bad_mtrack:
        flist = glob.glob(os.path.join(data_dir, "{}*".format(mtrack.track_id)))
        if len(flist) > 0:
            for f in flist:
                bname = os.path.basename(f)
                os.rename(f, os.path.join(new_dir, bname))

# %%
mtracks = mdb.load_all_multitracks(dataset_version=['V1'])
for mtrack in mtracks:
    if mtrack.has_melody:
        flist = glob.glob(os.path.join(data_dir, "{}*".format(mtrack.track_id)))
        if len(flist) > 0:
            for f in flist:
                print(f)
                os.remove(f)

# %%
rm /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/*/TrevorAndTheSoundwaves_AloneAndSad_multif0_complete*.npy

# %%
x = 5
print(x)
