# %% [markdown]
# Notebook used to compute input HCQTs and targets for every track for different task types
#
# In each cell we manually run a script with the given parameters

# %%
cd ../deepsalience
# Out:
# /scratch/rmb456/multif0/deepsalience

# %%
# import medleydb as mdb
# import numpy as np
# import os


# mel1_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/"
# mel2_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/"
# mel3_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/"
# mf0_incomplete = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/"
# mf0_complete = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/"

# mtracks = mdb.load_all_multitracks(
#     dataset_version=['V1', 'V2', 'EXTRA']
# )

# for mtrack in mtracks:
# #     print(mtrack.track_id)
#     fpath = os.path.join(mel1_dir, 'inputs', '{}_mel1_input.npy'.format(mtrack.track_id))
#     if not os.path.exists(fpath):
# #         print("   > no npy file")
#         continue

#     data = np.load(fpath, mmap_mode='r')

#     if data.shape[0] != 6:
#         print(mtrack.track_id)
#         print("   > {}".format(data.shape))
#         os.remove(fpath)
#         os.remove(os.path.join(mel2_dir, 'inputs', '{}_mel2_input.npy'.format(mtrack.track_id)))
#         os.remove(os.path.join(mel3_dir, 'inputs', '{}_mel3_input.npy'.format(mtrack.track_id)))
#         os.remove(os.path.join(mf0_incomplete, 'inputs', '{}_multif0_incomplete_input.npy'.format(mtrack.track_id)))

# %%
# %run compute_training_data.py --help
# Out:
# usage: compute_training_data.py [-h] [--use-mdb2] [--blur-labels]
#                                 save_dir option n_jobs precomputed_hcqt_path
#
# Generate feature files for multif0 learning.
#
# positional arguments:
#   save_dir              Path to save npy files.
#   option                Type of data to compute. One of 'solo_pitch'
#                         'melody1', 'melody2', 'melody3' 'multif0_incomplete',
#                         'multif0_complete'.
#   n_jobs                Number of jobs to run in parallel.
#   precomputed_hcqt_path
#                         Path to folder with hcqts precomputed
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --use-mdb2
#   --blur-labels

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/pitch/" "solo_pitch" -1 "" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/" "melody1" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs/" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/" "multif0_complete" -1 '' "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody2/" "melody2" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs/" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody3/" "melody3" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/" "multif0_incomplete" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/melody1/inputs" "--blur-labels"

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/" "bass" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/inputs" "--blur-labels"
# Out:
# AClassicEducation_NightOwl
#     > AClassicEducation_NightOwl already done!
# AimeeNorwich_Child
#     > AimeeNorwich_Child already done!
# AimeeNorwich_Flying
# AlexanderRoss_GoodbyeBolero
#     > AimeeNorwich_Flying already done!
#     > AlexanderRoss_GoodbyeBolero already done!
# AlexanderRoss_VelvetCurtain
#     > AlexanderRoss_VelvetCurtain already done!
#     ChrisJacoby_BoothShotLincoln No bass data
# AmarLal_Rest
#     AmarLal_Rest No bass data
# AmarLal_SpringDay1
#     AmarLal_SpringDay1 No bass data
# Auctioneer_OurFutureFaces
#     > Auctioneer_OurFutureFaces already done!
# AvaLuna_Waterduct
#     > AvaLuna_Waterduct already done!
# BigTroubles_Phantom
#     > BigTroubles_Phantom already done!
# BrandonWebster_DontHearAThing
#     BrandonWebster_DontHearAThing No bass data
# BrandonWebster_YesSirICanFly
#     BrandonWebster_YesSirICanFly No bass data
# CelestialShore_DieForUs
#     > CelestialShore_DieForUs already done!
# ChrisJacoby_BoothShotLincoln
# ChrisJacoby_PigsFoot
#     > ClaraBerryAndWooldog_WaltzForMyVictims already done!
#      > ChrisJacoby_PigsFoot Getting times and freqs...
# ClaraBerryAndWooldog_AirTraffic
#     > ClaraBerryAndWooldog_AirTraffic already done!
# ClaraBerryAndWooldog_Boys
#     ClaraBerryAndWooldog_Boys No bass data
# ClaraBerryAndWooldog_Stella
#     > ClaraBerryAndWooldog_Stella already done!
# ClaraBerryAndWooldog_TheBadGuys
#     ClaraBerryAndWooldog_TheBadGuys No bass data
# ClaraBerryAndWooldog_WaltzForMyVictims
# Creepoid_OldTree
#     > Creepoid_OldTree already done!
# CroqueMadame_Oil
#      > CroqueMadame_Oil Getting times and freqs...
# CroqueMadame_Pilot
#      > CroqueMadame_Pilot Getting times and freqs...
# Debussy_LenfantProdigue
#     Debussy_LenfantProdigue No bass data
# DreamersOfTheGhetto_HeavyLove
#     > DreamersOfTheGhetto_HeavyLove already done!
# EthanHein_1930sSynthAndUprightBass
#     > EthanHein_1930sSynthAndUprightBass already done!
# EthanHein_BluesForNofi
#     JoelHelander_Definition No bass data
#     > EthanHein_BluesForNofi already done!
# EthanHein_GirlOnABridge
#     EthanHein_GirlOnABridge No bass data
# EthanHein_HarmonicaFigure
#     EthanHein_HarmonicaFigure No bass data
# FacesOnFilm_WaitingForGa
#     > FacesOnFilm_WaitingForGa already done!
# FamilyBand_Again
#      > FamilyBand_Again Getting times and freqs...
# Grants_PunchDrunk
#     > Grants_PunchDrunk already done!
# Handel_TornamiAVagheggiar
#     Handel_TornamiAVagheggiar No bass data
# HeladoNegro_MitadDelMundo
#     HeladoNegro_MitadDelMundo No bass data
# HezekiahJones_BorrowedHeart
#     > HezekiahJones_BorrowedHeart already done!
# HopAlong_SisterCities
#     > HopAlong_SisterCities already done!
# InvisibleFamiliars_DisturbingWildlife
#     > InvisibleFamiliars_DisturbingWildlife already done!
# JoelHelander_Definition
# JoelHelander_ExcessiveResistancetoChange
#      > JoelHelander_ExcessiveResistancetoChange Getting times and freqs...
# Lushlife_ToynbeeSuite
# JoelHelander_IntheAtticBedroom
#     JoelHelander_IntheAtticBedroom No bass data
# KarimDouaidy_Hopscotch
#     > KarimDouaidy_Hopscotch already done!
# KarimDouaidy_Yatora
#     > KarimDouaidy_Yatora already done!
# LizNelson_Coldwar
#     LizNelson_Coldwar No bass data
# LizNelson_ImComingHome
#     LizNelson_ImComingHome No bass data
# LizNelson_Rainfall
#     LizNelson_Rainfall No bass data
#     > Lushlife_ToynbeeSuite already done!
# MatthewEntwistle_AnEveningWithOliver
#     > MatthewEntwistle_AnEveningWithOliver already done!
# MatthewEntwistle_DontYouEver
#     > MatthewEntwistle_DontYouEver already done!
# MatthewEntwistle_FairerHopes
#     > MatthewEntwistle_FairerHopes already done!
# MatthewEntwistle_ImpressionsOfSaturn
#     MatthewEntwistle_ImpressionsOfSaturn No bass data
# MatthewEntwistle_Lontano
#     Mozart_DiesBildnis No bass data
#     MatthewEntwistle_Lontano No bass data
# MatthewEntwistle_TheArch
#     MatthewEntwistle_TheArch No bass data
# MatthewEntwistle_TheFlaxenField
#     MatthewEntwistle_TheFlaxenField No bass data
# Meaxic_TakeAStep
#     > Meaxic_TakeAStep already done!
# Meaxic_YouListen
#     > Meaxic_YouListen already done!
# MichaelKropf_AllGoodThings
#     MichaelKropf_AllGoodThings No bass data
# Mozart_BesterJungling
#     Mozart_BesterJungling No bass data
# Mozart_DiesBildnis
# MusicDelta_80sRock
#     > MusicDelta_80sRock already done!
# MusicDelta_Beatles
#     > MusicDelta_Beatles already done!
# MusicDelta_BebopJazz
#     > MusicDelta_BebopJazz already done!
# MusicDelta_Beethoven
#     > MusicDelta_Beethoven already done!
# MusicDelta_Britpop
# MusicDelta_ChineseHenan
#     > MusicDelta_Britpop already done!
# MusicDelta_ChineseChaoZhou
#     MusicDelta_ChineseChaoZhou No bass data
# MusicDelta_ChineseDrama
#     MusicDelta_ChineseDrama No bass data
#     MusicDelta_ChineseHenan No bass data
# MusicDelta_ChineseJiangNan
#     MusicDelta_ChineseJiangNan No bass data
# MusicDelta_ChineseXinJing
#     MusicDelta_ChineseXinJing No bass data
# MusicDelta_ChineseYaoZu
#     MusicDelta_ChineseYaoZu No bass data
# MusicDelta_CoolJazz
#     > MusicDelta_CoolJazz already done!
# MusicDelta_Country1
#     > MusicDelta_Country1 already done!
# MusicDelta_Country2
#     > MusicDelta_Country2 already done!
# MusicDelta_Disco
#     > MusicDelta_Disco already done!
# MusicDelta_FreeJazz
#     > MusicDelta_FreeJazz already done!
# MusicDelta_FunkJazz
#     > MusicDelta_FunkJazz already done!
# MusicDelta_FusionJazz
#     > MusicDelta_FusionJazz already done!
# MusicDelta_Gospel
# MusicDelta_Grunge
#     > MusicDelta_Gospel already done!
# MusicDelta_GriegTrolltog
#     > MusicDelta_GriegTrolltog already done!
#     > MusicDelta_Grunge already done!
# MusicDelta_Hendrix
#     > MusicDelta_Hendrix already done!
# MusicDelta_InTheHalloftheMountainKing
#     > MusicDelta_InTheHalloftheMountainKing already done!
# MusicDelta_Rockabilly
# MusicDelta_LatinJazz
#     > MusicDelta_LatinJazz already done!
# MusicDelta_ModalJazz
#     > MusicDelta_ModalJazz already done!
# MusicDelta_Pachelbel
#     MusicDelta_Pachelbel No bass data
# MusicDelta_Punk
#     > MusicDelta_Punk already done!
# MusicDelta_Reggae
#     > MusicDelta_Reggae already done!
# MusicDelta_Rock
#     > MusicDelta_Rock already done!
#     > MusicDelta_Rockabilly already done!
# MusicDelta_Shadows
#      > Phoenix_SeanCaughlinsTheScartaglen Getting times and freqs...
#     > MusicDelta_Shadows already done!
# MusicDelta_SpeedMetal
#     > MusicDelta_SpeedMetal already done!
# MusicDelta_SwingJazz
#     > MusicDelta_SwingJazz already done!
# MusicDelta_Vivaldi
#     > MusicDelta_Vivaldi already done!
# MusicDelta_Zeppelin
#     > MusicDelta_Zeppelin already done!
# NightPanther_Fire
#     > NightPanther_Fire already done!
# Phoenix_BrokenPledgeChicagoReel
#     Phoenix_BrokenPledgeChicagoReel No bass data
# Phoenix_ColliersDaughter
#      > Phoenix_ColliersDaughter Getting times and freqs...
# Phoenix_ElzicsFarewell
#     Phoenix_ElzicsFarewell No bass data
# Phoenix_LarkOnTheStrandDrummondCastle
#     Phoenix_LarkOnTheStrandDrummondCastle No bass data
# Phoenix_ScotchMorris
#     Phoenix_ScotchMorris No bass data
# Phoenix_SeanCaughlinsTheScartaglen
# PortStWillow_StayEven
#     TablaBreakbeatScience_MiloVsMongo No bass data
#     > PortStWillow_StayEven already done!
# PurlingHiss_Lolita
#      > PurlingHiss_Lolita Getting times and freqs...
# Schubert_Erstarrung
#     Schubert_Erstarrung No bass data
# Schumann_Mignon
#     Schumann_Mignon No bass data
# SecretMountains_HighHorse
#     > SecretMountains_HighHorse already done!
# Snowmine_Curfews
#     > Snowmine_Curfews already done!
# StevenClark_Bounty
#     > StevenClark_Bounty already done!
# StrandOfOaks_Spacestation
#     > StrandOfOaks_Spacestation already done!
# SweetLights_YouLetMeDown
#     > SweetLights_YouLetMeDown already done!
# TablaBreakbeatScience_Animoog
#     > TablaBreakbeatScience_Animoog already done!
# TablaBreakbeatScience_CaptainSky
#     > TablaBreakbeatScience_CaptainSky already done!
# TablaBreakbeatScience_MiloVsMongo
# TablaBreakbeatScience_MoodyPlucks
# TablaBreakbeatScience_Scorpio
#     TablaBreakbeatScience_MoodyPlucks No bass data
# TablaBreakbeatScience_PhaseTransition
#     > TablaBreakbeatScience_PhaseTransition already done!
# TablaBreakbeatScience_RockSteady
#     TablaBreakbeatScience_RockSteady No bass data
#     TablaBreakbeatScience_Scorpio No bass data
# TablaBreakbeatScience_Vger
#     TablaBreakbeatScience_Vger No bass data
# TablaBreakbeatScience_WhoIsIt
#     > TablaBreakbeatScience_WhoIsIt already done!
# TheDistricts_Vermont
#     > TheDistricts_Vermont already done!
# TheScarletBrand_LesFleursDuMal
#     > TheScarletBrand_LesFleursDuMal already done!
# TheSoSoGlos_Emergency
#     > TheSoSoGlos_Emergency already done!
# Wolf_DieBekherte
#     Wolf_DieBekherte No bass data
# Allegria_MendelssohnMovement1
#     Allegria_MendelssohnMovement1 No bass data
# AmadeusRedux_MozartAllegro
#     AmadeusRedux_MozartAllegro No bass data
# AmadeusRedux_SchubertMovement2
#      > CassandraJenkins_PerfectDay Getting times and freqs...
#      > AmadeusRedux_SchubertMovement2 Getting times and freqs...
# AmadeusRedux_SchubertMovement3
#      > AmadeusRedux_SchubertMovement3 Getting times and freqs...
# BarefootSisters_RedJetta
#     BarefootSisters_RedJetta No bass data
# CassandraJenkins_PerfectDay
#      > CassandraJenkins_PerfectDay Getting input/output pairs...
#     > using precomputed CQT for CassandraJenkins_PerfectDay_MIX.wav
# FallingSparks_Improvisation3
#      > FilthyBird_IdLikeToKnow Getting times and freqs...
#      > FallingSparks_Improvisation3 Getting times and freqs...
# FallingSparks_PakKlongTalad
#      > FallingSparks_PakKlongTalad Getting times and freqs...
# FennelCartwright_DearTessie
#     FennelCartwright_DearTessie No bass data
# FennelCartwright_FlowerDrumSong
#      > FennelCartwright_FlowerDrumSong Getting times and freqs...
# FennelCartwright_WinterLake
#      > FennelCartwright_WinterLake Getting times and freqs...
# FilthyBird_IdLikeToKnow
#      > FilthyBird_IdLikeToKnow Getting input/output pairs...
#     > using precomputed CQT for FilthyBird_IdLikeToKnow_MIX.wav
# Katzn_CharlieKnox
#     Katzn_CharlieKnox No bass data
# LewisAndClarke_TheSilverSea
#      > LewisAndClarke_TheSilverSea Getting times and freqs...
#      > LittleTybee_TheAlchemist Getting times and freqs...
# LittleTybee_TheAlchemist
#      > LittleTybee_TheAlchemist Getting input/output pairs...
#     > using precomputed CQT for LittleTybee_TheAlchemist_MIX.wav
# PoliceHearingDepartment_SchumannMovement2
# SasquatchConnection_HolyClamsBatman
#      > PoliceHearingDepartment_SchumannMovement2 Getting times and freqs...
# PoliceHearingDepartment_VivaldiMovement1
#      > PoliceHearingDepartment_VivaldiMovement1 Getting times and freqs...
# PoliceHearingDepartment_VivaldiMovement2
#      > PoliceHearingDepartment_VivaldiMovement2 Getting times and freqs...
# PoliceHearingDepartment_VivaldiMovement3
#      > PoliceHearingDepartment_VivaldiMovement3 Getting times and freqs...
# QuantumChromos_Circuits
#      > QuantumChromos_Circuits Getting times and freqs...
# RodrigoBonelli_BalladForLaura
#      > RodrigoBonelli_BalladForLaura Getting times and freqs...
# SasquatchConnection_BoomBoxing
#      > SasquatchConnection_BoomBoxing Getting times and freqs...
#      > SasquatchConnection_HolyClamsBatman Getting times and freqs...
# SasquatchConnection_Illuminati
#      > SasquatchConnection_Illuminati Getting times and freqs...
# SasquatchConnection_Struttin
#      > SasquatchConnection_Struttin Getting times and freqs...
# SasquatchConnection_ThanksALatte
#      > SasquatchConnection_ThanksALatte Getting times and freqs...
# SlowGhost_FirstSnow
#      > SlowGhost_FirstSnow Getting times and freqs...
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    4.2s
#      > SlowGhost_FirstSnow Getting input/output pairs...
#     > using precomputed CQT for SlowGhost_FirstSnow_MIX.wav
# SlowGhost_MidnightGroove
#      > SlowGhost_MidnightGroove Getting times and freqs...
# TheFranckDuo_FranckViolinSonataInAMajorMovement1
#     TheFranckDuo_FranckViolinSonataInAMajorMovement1 No bass data
# TheFranckDuo_FranckViolinSonataInAMajorMovement2
#     TheFranckDuo_FranckViolinSonataInAMajorMovement2 No bass data
# TheKitchenettes_Alive
#      > TheKitchenettes_Alive Getting times and freqs...
#      > SlowGhost_MidnightGroove Getting input/output pairs...
#     > using precomputed CQT for SlowGhost_MidnightGroove_MIX.wav
#      > TheKitchenettes_Alive Getting input/output pairs...
#     > using precomputed CQT for TheKitchenettes_Alive_MIX.wav
#     Saved data for LittleTybee_TheAlchemist_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# MatthewEntwistle_ReturnToVenezia
#     MatthewEntwistle_ReturnToVenezia No bass data
# MidnightBlue_HuntingSeason
#      > MidnightBlue_HuntingSeason Getting times and freqs...
#      > MidnightBlue_HuntingSeason Getting input/output pairs...
#     > using precomputed CQT for MidnightBlue_HuntingSeason_MIX.wav
#     Saved data for FilthyBird_IdLikeToKnow_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# FruitCathedral_KeepMeRunnin
#      > FruitCathedral_KeepMeRunnin Getting times and freqs...
#      > FruitCathedral_KeepMeRunnin Getting input/output pairs...
#     > using precomputed CQT for FruitCathedral_KeepMeRunnin_MIX.wav
#     Saved data for TheKitchenettes_Alive_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TheNoHoStringOrchestra_ElgarMovement1
#      > TheNoHoStringOrchestra_ElgarMovement1 Getting times and freqs...
# TheNoHoStringOrchestra_ElgarMovement2
#      > TheNoHoStringOrchestra_ElgarMovement2 Getting times and freqs...
# TheNoHoStringOrchestra_ElgarMovement3
#      > TheNoHoStringOrchestra_ElgarMovement3 Getting times and freqs...
# TheTonTons_Lush
#      > TheTonTons_Lush Getting times and freqs...
#      > TheTonTons_Lush Getting input/output pairs...
#     > using precomputed CQT for TheTonTons_Lush_MIX.wav
#     Saved data for CassandraJenkins_PerfectDay_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# CatMartino_IPromise
#     CatMartino_IPromise No bass data
# Cayetana_MissThing
#      > Cayetana_MissThing Getting times and freqs...
#      > Cayetana_MissThing Getting input/output pairs...
#     > using precomputed CQT for Cayetana_MissThing_MIX.wav
#     Saved data for SlowGhost_FirstSnow_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# AHa_TakeOnMe
#     AHa_TakeOnMe No bass data
# AcDc_BackInBlack
#      > AcDc_BackInBlack Getting times and freqs...
#      > AcDc_BackInBlack Getting input/output pairs...
#     > using precomputed CQT for AcDc_BackInBlack_MIX.wav
#     Saved data for MidnightBlue_HuntingSeason_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# MidnightBlue_StarsAreScreaming
#      > MidnightBlue_StarsAreScreaming Getting times and freqs...
#      > MidnightBlue_StarsAreScreaming Getting input/output pairs...
#     > using precomputed CQT for MidnightBlue_StarsAreScreaming_MIX.wav
#     Saved data for TheTonTons_Lush_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TleilaxEnsemble_Late
#      > TleilaxEnsemble_Late Getting times and freqs...
# TleilaxEnsemble_MelancholyFlowers
#      > TleilaxEnsemble_MelancholyFlowers Getting times and freqs...
# Torres_NewSkin
#      > Torres_NewSkin Getting times and freqs...
#      > Torres_NewSkin Getting input/output pairs...
#     > using precomputed CQT for Torres_NewSkin_MIX.wav
#     Saved data for Cayetana_MissThing_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# DahkaBand_SoldierMan
#      > DahkaBand_SoldierMan Getting times and freqs...
# DeadMilkmen_PrisonersCinema
#      > DeadMilkmen_PrisonersCinema Getting times and freqs...
#      > DeadMilkmen_PrisonersCinema Getting input/output pairs...
#     > using precomputed CQT for DeadMilkmen_PrisonersCinema_MIX.wav
#     Saved data for SlowGhost_MidnightGroove_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# SlowGhost_Peanut
#      > SlowGhost_Peanut Getting times and freqs...
#      > SlowGhost_Peanut Getting input/output pairs...
#     > using precomputed CQT for SlowGhost_Peanut_MIX.wav
#     Saved data for FruitCathedral_KeepMeRunnin_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# HopsNVinyl_ChickenFriedSteak
#      > HopsNVinyl_ChickenFriedSteak Getting times and freqs...
# HopsNVinyl_HoneyBrown
#      > HopsNVinyl_HoneyBrown Getting times and freqs...
# HopsNVinyl_ReignCheck
#      > HopsNVinyl_ReignCheck Getting times and freqs...
# HopsNVinyl_WidowsWalk
#      > HopsNVinyl_WidowsWalk Getting times and freqs...
# Karachacha_Volamos
#      > Karachacha_Volamos Getting times and freqs...
# AnEndlessSporadic_Anything
#      > AnEndlessSporadic_Anything Getting times and freqs...
#      > AnEndlessSporadic_Anything Getting input/output pairs...
#     > using precomputed CQT for AnEndlessSporadic_Anything_MIX.wav
#     Saved data for AcDc_BackInBlack_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Adele_SomeoneLikeYou
#     Adele_SomeoneLikeYou No bass data
# Aerosmith_LoveInAnElevator
#      > Aerosmith_LoveInAnElevator Getting times and freqs...
#      > Aerosmith_LoveInAnElevator Getting input/output pairs...
#     > using precomputed CQT for Aerosmith_LoveInAnElevator_MIX.wav
#     Saved data for MidnightBlue_StarsAreScreaming_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# MutualBenefit_NotForNothing
#      > MutualBenefit_NotForNothing Getting times and freqs...
#      > MutualBenefit_NotForNothing Getting input/output pairs...
#     > using precomputed CQT for MutualBenefit_NotForNothing_MIX.wav
#     Saved data for DeadMilkmen_PrisonersCinema_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# DeclareAString_MendelssohnPianoTrio1Movement1
#     DeclareAString_MendelssohnPianoTrio1Movement1 No bass data
# DeclareAString_MendelssohnPianoTrio1Movement2
#     DeclareAString_MendelssohnPianoTrio1Movement2 No bass data
# FallingSparks_Improvisation1
#      > FallingSparks_Improvisation1 Getting times and freqs...
# FallingSparks_Improvisation2
#      > FallingSparks_Improvisation2 Getting times and freqs...
# BlackEyedPeas_IGottaFeeling
#     BlackEyedPeas_IGottaFeeling No bass data
# BlackSabbath_WarPigs
#      > BlackSabbath_WarPigs Getting times and freqs...
#      > BlackSabbath_WarPigs Getting input/output pairs...
#     > using precomputed CQT for BlackSabbath_WarPigs_MIX.wav
#     Saved data for Torres_NewSkin_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TrevorAndTheSoundwaves_AloneAndSad
#      > TrevorAndTheSoundwaves_AloneAndSad Getting times and freqs...
#      > TrevorAndTheSoundwaves_AloneAndSad Getting input/output pairs...
#     > using precomputed CQT for TrevorAndTheSoundwaves_AloneAndSad_MIX.wav
#     Saved data for AnEndlessSporadic_Anything_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Anberlin_TheFeelGoodDrag
#      > Anberlin_TheFeelGoodDrag Getting times and freqs...
#      > Anberlin_TheFeelGoodDrag Getting input/output pairs...
#     > using precomputed CQT for Anberlin_TheFeelGoodDrag_MIX.wav
#     Saved data for SlowGhost_Peanut_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# SlowGhost_YoureAMystery
#      > SlowGhost_YoureAMystery Getting times and freqs...
#      > SlowGhost_YoureAMystery Getting input/output pairs...
#     > using precomputed CQT for SlowGhost_YoureAMystery_MIX.wav
#     Saved data for MutualBenefit_NotForNothing_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# PatternIsMovement_SaveMe
#     PatternIsMovement_SaveMe No bass data
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost
#      > PeterMatthewBauer_YouAlwaysLookForSomeoneLost Getting times and freqs...
#      > PeterMatthewBauer_YouAlwaysLookForSomeoneLost Getting input/output pairs...
#     > using precomputed CQT for PeterMatthewBauer_YouAlwaysLookForSomeoneLost_MIX.wav
#     Saved data for Anberlin_TheFeelGoodDrag_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# ArcadeFire_BlackMirror
#      > ArcadeFire_BlackMirror Getting times and freqs...
#      > ArcadeFire_BlackMirror Getting input/output pairs...
#     > using precomputed CQT for ArcadeFire_BlackMirror_MIX.wav
#     Saved data for Aerosmith_LoveInAnElevator_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# AlanisMorissette_YouOughtaKnow
#      > AlanisMorissette_YouOughtaKnow Getting times and freqs...
#      > AlanisMorissette_YouOughtaKnow Getting input/output pairs...
#     > using precomputed CQT for AlanisMorissette_YouOughtaKnow_MIX.wav
#     Saved data for TrevorAndTheSoundwaves_AloneAndSad_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Verdi_IlTrovatore
#     Verdi_IlTrovatore No bass data
# Boston_MoreThanAFeeling
#      > Boston_MoreThanAFeeling Getting times and freqs...
#      > Boston_MoreThanAFeeling Getting input/output pairs...
#     > using precomputed CQT for Boston_MoreThanAFeeling_MIX.wav
#     Saved data for SlowGhost_YoureAMystery_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# SongYiJeon_TwoMoons
#     SongYiJeon_TwoMoons No bass data
# Sweat_AlmostAlways
#     Sweat_AlmostAlways No bass data
# Sweat_Anecdoche
#     Sweat_Anecdoche No bass data
# Sweat_Elegy
#     Sweat_Elegy No bass data
# Sweat_Mesozoic
#     Sweat_Mesozoic No bass data
# Sweat_Sn1572
#      > Sweat_Sn1572 Getting times and freqs...
# Sweat_Tact
#     Sweat_Tact No bass data
# TemperedElan_DorothyJeanne
#     TemperedElan_DorothyJeanne No bass data
# TemperedElan_WiseOne
#     TemperedElan_WiseOne No bass data
# BryanAdams_SummerOf69
#      > BryanAdams_SummerOf69 Getting times and freqs...
#      > BryanAdams_SummerOf69 Getting input/output pairs...
#     > using precomputed CQT for BryanAdams_SummerOf69_MIX.wav
#     Saved data for BlackSabbath_WarPigs_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Blink182_AllTheSmallThings
#      > Blink182_AllTheSmallThings Getting times and freqs...
#      > Blink182_AllTheSmallThings Getting input/output pairs...
#     > using precomputed CQT for Blink182_AllTheSmallThings_MIX.wav
#     Saved data for ArcadeFire_BlackMirror_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# ArcticMonkeys_Brainstorm
#      > ArcticMonkeys_Brainstorm Getting times and freqs...
#      > ArcticMonkeys_Brainstorm Getting input/output pairs...
#     > using precomputed CQT for ArcticMonkeys_Brainstorm_MIX.wav
#     Saved data for AlanisMorissette_YouOughtaKnow_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# AllThatRemains_Chiron
#      > AllThatRemains_Chiron Getting times and freqs...
#      > AllThatRemains_Chiron Getting input/output pairs...
#     > using precomputed CQT for AllThatRemains_Chiron_MIX.wav
#     Saved data for PeterMatthewBauer_YouAlwaysLookForSomeoneLost_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Plasma_GoodShout
#      > Plasma_GoodShout Getting times and freqs...
#      > Plasma_GoodShout Getting input/output pairs...
#     > using precomputed CQT for Plasma_GoodShout_MIX.wav
#     Saved data for Boston_MoreThanAFeeling_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# BradPaisley_MudOnTheTires
#      > BradPaisley_MudOnTheTires Getting times and freqs...
#      > BradPaisley_MudOnTheTires Getting input/output pairs...
#     > using precomputed CQT for BradPaisley_MudOnTheTires_MIX.wav
#     Saved data for Blink182_AllTheSmallThings_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Blondie_OneWayOrAnother
#      > Blondie_OneWayOrAnother Getting times and freqs...
#      > Blondie_OneWayOrAnother Getting input/output pairs...
#     > using precomputed CQT for Blondie_OneWayOrAnother_MIX.wav
#     Saved data for ArcticMonkeys_Brainstorm_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# BillyIdol_WhiteWedding
#      > BillyIdol_WhiteWedding Getting times and freqs...
#      > BillyIdol_WhiteWedding Getting input/output pairs...
#     > using precomputed CQT for BillyIdol_WhiteWedding_MIX.wav
#     Saved data for BryanAdams_SummerOf69_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Bush_Machinehead
#      > Bush_Machinehead Getting times and freqs...
#      > Bush_Machinehead Getting input/output pairs...
#     > using precomputed CQT for Bush_Machinehead_MIX.wav
#     Saved data for Plasma_GoodShout_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# PoliceHearingDepartment_Brahms
#     PoliceHearingDepartment_Brahms No bass data
# PoliceHearingDepartment_SchumannMovement1
#     PoliceHearingDepartment_SchumannMovement1 No bass data
# CherryPoppinDaddies_ZootSuitRiot
#      > CherryPoppinDaddies_ZootSuitRiot Getting times and freqs...
#      > CherryPoppinDaddies_ZootSuitRiot Getting input/output pairs...
#     > using precomputed CQT for CherryPoppinDaddies_ZootSuitRiot_MIX.wav
#     Saved data for AllThatRemains_Chiron_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Coldplay_InMyPlace
#     Coldplay_InMyPlace No bass data
# Coldplay_Shiver
#      > Coldplay_Shiver Getting times and freqs...
#      > Coldplay_Shiver Getting input/output pairs...
#     > using precomputed CQT for Coldplay_Shiver_MIX.wav
#     Saved data for BradPaisley_MudOnTheTires_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# BrooksDunn_HillbillyDeluxe
#      > BrooksDunn_HillbillyDeluxe Getting times and freqs...
#      > BrooksDunn_HillbillyDeluxe Getting input/output pairs...
#     > using precomputed CQT for BrooksDunn_HillbillyDeluxe_MIX.wav
#     Saved data for Blondie_OneWayOrAnother_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# BlueOysterCult_DontFearTheReaper
#      > BlueOysterCult_DontFearTheReaper Getting times and freqs...
#      > BlueOysterCult_DontFearTheReaper Getting input/output pairs...
#     > using precomputed CQT for BlueOysterCult_DontFearTheReaper_MIX.wav
#     Saved data for BillyIdol_WhiteWedding_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# BillySquier_TheStroke
#      > BillySquier_TheStroke Getting times and freqs...
#      > BillySquier_TheStroke Getting input/output pairs...
#     > using precomputed CQT for BillySquier_TheStroke_MIX.wav
#     Saved data for Bush_Machinehead_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# CarlDouglas_KungFuFighting
#      > CarlDouglas_KungFuFighting Getting times and freqs...
#      > CarlDouglas_KungFuFighting Getting input/output pairs...
#     > using precomputed CQT for CarlDouglas_KungFuFighting_MIX.wav
#     Saved data for CherryPoppinDaddies_ZootSuitRiot_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# ChrisBrown_Yeah
#      > ChrisBrown_Yeah Getting times and freqs...
#      > ChrisBrown_Yeah Getting input/output pairs...
#     > using precomputed CQT for ChrisBrown_Yeah_MIX.wav
#     Saved data for BrooksDunn_HillbillyDeluxe_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# BrunoMars_Grenade
#      > BrunoMars_Grenade Getting times and freqs...
#      > BrunoMars_Grenade Getting input/output pairs...
#     > using precomputed CQT for BrunoMars_Grenade_MIX.wav
#     Saved data for Coldplay_Shiver_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# CorinneBaileyRae_PutYourRecordsOn
#      > CorinneBaileyRae_PutYourRecordsOn Getting times and freqs...
#      > CorinneBaileyRae_PutYourRecordsOn Getting input/output pairs...
#     > using precomputed CQT for CorinneBaileyRae_PutYourRecordsOn_MIX.wav
#     Saved data for CarlDouglas_KungFuFighting_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# CarrieUnderwood_HomeSweetHome
#      > CarrieUnderwood_HomeSweetHome Getting times and freqs...
#      > CarrieUnderwood_HomeSweetHome Getting input/output pairs...
#     > using precomputed CQT for CarrieUnderwood_HomeSweetHome_MIX.wav
#     Saved data for BillySquier_TheStroke_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# CountZero_Shake
#      > CountZero_Shake Getting times and freqs...
#      > CountZero_Shake Getting input/output pairs...
#     > using precomputed CQT for CountZero_Shake_MIX.wav
#     Saved data for BlueOysterCult_DontFearTheReaper_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# BobSeger_OldTimeRockAndRoll
#      > BobSeger_OldTimeRockAndRoll Getting times and freqs...
#      > BobSeger_OldTimeRockAndRoll Getting input/output pairs...
#     > using precomputed CQT for BobSeger_OldTimeRockAndRoll_MIX.wav
#     Saved data for ChrisBrown_Yeah_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# ChristinaAguilera_GenieInABottle
#      > ChristinaAguilera_GenieInABottle Getting times and freqs...
#      > ChristinaAguilera_GenieInABottle Getting input/output pairs...
#     > using precomputed CQT for ChristinaAguilera_GenieInABottle_MIX.wav
#     Saved data for CorinneBaileyRae_PutYourRecordsOn_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# FleetwoodMac_Rhiannon
#      > FleetwoodMac_Rhiannon Getting times and freqs...
#      > FleetwoodMac_Rhiannon Getting input/output pairs...
#     > using precomputed CQT for FleetwoodMac_Rhiannon_MIX.wav
#     Saved data for BrunoMars_Grenade_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# BrunoMars_JustTheWayYouAre
#      > BrunoMars_JustTheWayYouAre Getting times and freqs...
#      > BrunoMars_JustTheWayYouAre Getting input/output pairs...
#     > using precomputed CQT for BrunoMars_JustTheWayYouAre_MIX.wav
#     Saved data for CarrieUnderwood_HomeSweetHome_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# CeeloGreen_ForgetYou
#      > CeeloGreen_ForgetYou Getting times and freqs...
#      > CeeloGreen_ForgetYou Getting input/output pairs...
#     > using precomputed CQT for CeeloGreen_ForgetYou_MIX.wav
#     Saved data for BobSeger_OldTimeRockAndRoll_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# FlightOfTheConcords_BusinessTime
#      > FlightOfTheConcords_BusinessTime Getting times and freqs...
#      > FlightOfTheConcords_BusinessTime Getting input/output pairs...
#     > using precomputed CQT for FlightOfTheConcords_BusinessTime_MIX.wav
#     Saved data for CountZero_Shake_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# CountingCrows_AccidentallyInLove
#      > CountingCrows_AccidentallyInLove Getting times and freqs...
#      > CountingCrows_AccidentallyInLove Getting input/output pairs...
#     > using precomputed CQT for CountingCrows_AccidentallyInLove_MIX.wav
#     Saved data for ChristinaAguilera_GenieInABottle_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Chromeo_Tenderoni
#     Chromeo_Tenderoni No bass data
# Chumbawamba_Tubthumping
#     Chumbawamba_Tubthumping No bass data
# ColdWarKids_HangMeUpToDry
#      > ColdWarKids_HangMeUpToDry Getting times and freqs...
#      > ColdWarKids_HangMeUpToDry Getting input/output pairs...
#     > using precomputed CQT for ColdWarKids_HangMeUpToDry_MIX.wav
#     Saved data for BrunoMars_JustTheWayYouAre_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# BrunoMars_MarryYou
#      > BrunoMars_MarryYou Getting times and freqs...
#      > BrunoMars_MarryYou Getting input/output pairs...
#     > using precomputed CQT for BrunoMars_MarryYou_MIX.wav
#     Saved data for FleetwoodMac_Rhiannon_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# FooFighters_AllMyLife
#      > FooFighters_AllMyLife Getting times and freqs...
#      > FooFighters_AllMyLife Getting input/output pairs...
#     > using precomputed CQT for FooFighters_AllMyLife_MIX.wav
#     Saved data for CeeloGreen_ForgetYou_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# CheapTrick_IWantYouToWantMe
#      > CheapTrick_IWantYouToWantMe Getting times and freqs...
#      > CheapTrick_IWantYouToWantMe Getting input/output pairs...
#     > using precomputed CQT for CheapTrick_IWantYouToWantMe_MIX.wav
#     Saved data for CountingCrows_AccidentallyInLove_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# CrazyFrog_JingleBells
#     CrazyFrog_JingleBells No bass data
# Incubus_Drive
#      > Incubus_Drive Getting times and freqs...
#      > Incubus_Drive Getting input/output pairs...
#     > using precomputed CQT for Incubus_Drive_MIX.wav
#     Saved data for FlightOfTheConcords_BusinessTime_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Inxs_NeedYouTonight
#     Inxs_NeedYouTonight No bass data
# KaiserChiefs_Ruby
#      > KaiserChiefs_Ruby Getting times and freqs...
#      > KaiserChiefs_Ruby Getting input/output pairs...
#     > using precomputed CQT for KaiserChiefs_Ruby_MIX.wav
#     Saved data for ColdWarKids_HangMeUpToDry_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Kansas_CarryOnMyWaywardSon
#      > Kansas_CarryOnMyWaywardSon Getting times and freqs...
#      > Kansas_CarryOnMyWaywardSon Getting input/output pairs...
#     > using precomputed CQT for Kansas_CarryOnMyWaywardSon_MIX.wav
#     Saved data for BrunoMars_MarryYou_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# KanyeWest_LoveLockdown
#     KanyeWest_LoveLockdown No bass data
# KeithUrban_IToldYouSo
#      > KeithUrban_IToldYouSo Getting times and freqs...
#      > KeithUrban_IToldYouSo Getting input/output pairs...
#     > using precomputed CQT for KeithUrban_IToldYouSo_MIX.wav
#     Saved data for CheapTrick_IWantYouToWantMe_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# KennyChesney_SheThinksMyTractorsSexy
#      > KennyChesney_SheThinksMyTractorsSexy Getting times and freqs...
#      > KennyChesney_SheThinksMyTractorsSexy Getting input/output pairs...
#     > using precomputed CQT for KennyChesney_SheThinksMyTractorsSexy_MIX.wav
#     Saved data for FooFighters_AllMyLife_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# KingsOfLeon_SexOnFire
#      > KingsOfLeon_SexOnFire Getting times and freqs...
# Kiss_RockAndRollAllNite
#      > Kiss_RockAndRollAllNite Getting times and freqs...
#      > Kiss_RockAndRollAllNite Getting input/output pairs...
#     > using precomputed CQT for Kiss_RockAndRollAllNite_MIX.wav
#     Saved data for Incubus_Drive_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Knack_MySharona
#      > Knack_MySharona Getting times and freqs...
#      > Knack_MySharona Getting input/output pairs...
#     > using precomputed CQT for Knack_MySharona_MIX.wav
#     Saved data for KaiserChiefs_Ruby_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Korn_FreakOnALeash
#      > Korn_FreakOnALeash Getting times and freqs...
#      > Korn_FreakOnALeash Getting input/output pairs...
#     > using precomputed CQT for Korn_FreakOnALeash_MIX.wav
#     Saved data for Kiss_RockAndRollAllNite_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# KtTunstall_BlackHorseAndTheCherryTree
#      > KtTunstall_BlackHorseAndTheCherryTree Getting times and freqs...
#      > KtTunstall_BlackHorseAndTheCherryTree Getting input/output pairs...
#     > using precomputed CQT for KtTunstall_BlackHorseAndTheCherryTree_MIX.wav
#     Saved data for Kansas_CarryOnMyWaywardSon_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# KtTunstall_SuddenlyISee
#      > KtTunstall_SuddenlyISee Getting times and freqs...
#      > KtTunstall_SuddenlyISee Getting input/output pairs...
#     > using precomputed CQT for KtTunstall_SuddenlyISee_MIX.wav
#     Saved data for KennyChesney_SheThinksMyTractorsSexy_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# LaRoux_Bulletproof
#     LaRoux_Bulletproof No bass data
# LadyGagaFeaturingBeyonce_Telephone
#     LadyGagaFeaturingBeyonce_Telephone No bass data
# LadyGaga_BadRomance
#     LadyGaga_BadRomance No bass data
# LadyGaga_BornThisWay
#     LadyGaga_BornThisWay No bass data
# LambOfGod_Requiem
#      > LambOfGod_Requiem Getting times and freqs...
#      > LambOfGod_Requiem Getting input/output pairs...
#     > using precomputed CQT for LambOfGod_Requiem_MIX.wav
#     Saved data for KeithUrban_IToldYouSo_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# LennyKravitz_AreYouGonnaGoMyWay
#      > LennyKravitz_AreYouGonnaGoMyWay Getting times and freqs...
#      > LennyKravitz_AreYouGonnaGoMyWay Getting input/output pairs...
#     > using precomputed CQT for LennyKravitz_AreYouGonnaGoMyWay_MIX.wav
#     Saved data for Korn_FreakOnALeash_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# LilyAllen_NotFair
#      > LilyAllen_NotFair Getting times and freqs...
#      > LilyAllen_NotFair Getting input/output pairs...
#     > using precomputed CQT for LilyAllen_NotFair_MIX.wav
#     Saved data for Knack_MySharona_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# LinkinPark_InTheEnd
#      > LinkinPark_InTheEnd Getting times and freqs...
#      > LinkinPark_InTheEnd Getting input/output pairs...
#     > using precomputed CQT for LinkinPark_InTheEnd_MIX.wav
#     Saved data for KtTunstall_BlackHorseAndTheCherryTree_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Lit_MyOwnWorstEnemy
#      > Lit_MyOwnWorstEnemy Getting times and freqs...
#      > Lit_MyOwnWorstEnemy Getting input/output pairs...
#     > using precomputed CQT for Lit_MyOwnWorstEnemy_MIX.wav
#     Saved data for KtTunstall_SuddenlyISee_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Live_IAlone
#      > Live_IAlone Getting times and freqs...
#      > Live_IAlone Getting input/output pairs...
#     > using precomputed CQT for Live_IAlone_MIX.wav
#     Saved data for LennyKravitz_AreYouGonnaGoMyWay_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# LoquilloYLosTrogloditas_CadillacSolitario
#      > LoquilloYLosTrogloditas_CadillacSolitario Getting times and freqs...
# LosLobos_LaBamba
#      > LosLobos_LaBamba Getting times and freqs...
#      > LosLobos_LaBamba Getting input/output pairs...
#     > using precomputed CQT for LosLobos_LaBamba_MIX.wav
#     Saved data for LambOfGod_Requiem_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# LynyrdSkynyrd_FreeBird
#      > LynyrdSkynyrd_FreeBird Getting times and freqs...
#      > LynyrdSkynyrd_FreeBird Getting input/output pairs...
#     > using precomputed CQT for LynyrdSkynyrd_FreeBird_MIX.wav
#     Saved data for LilyAllen_NotFair_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Maroon5_ThisLove
#      > Maroon5_ThisLove Getting times and freqs...
#      > Maroon5_ThisLove Getting input/output pairs...
#     > using precomputed CQT for Maroon5_ThisLove_MIX.wav
#     Saved data for Lit_MyOwnWorstEnemy_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# MartinaMcbride_ThisOnesForTheGirls
#      > MartinaMcbride_ThisOnesForTheGirls Getting times and freqs...
#      > MartinaMcbride_ThisOnesForTheGirls Getting input/output pairs...
#     > using precomputed CQT for MartinaMcbride_ThisOnesForTheGirls_MIX.wav
#     Saved data for LinkinPark_InTheEnd_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# MarvinGaye_IHeardItThroughTheGrapevine
#      > MarvinGaye_IHeardItThroughTheGrapevine Getting times and freqs...
#      > MarvinGaye_IHeardItThroughTheGrapevine Getting input/output pairs...
#     > using precomputed CQT for MarvinGaye_IHeardItThroughTheGrapevine_MIX.wav
#     Saved data for LosLobos_LaBamba_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# MarvinGaye_WhatsGoingOn
#      > MarvinGaye_WhatsGoingOn Getting times and freqs...
#      > MarvinGaye_WhatsGoingOn Getting input/output pairs...
#     > using precomputed CQT for MarvinGaye_WhatsGoingOn_MIX.wav
#     Saved data for Live_IAlone_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe
#      > McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe Getting times and freqs...
#      > McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe Getting input/output pairs...
#     > using precomputed CQT for McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe_MIX.wav
#     Saved data for Maroon5_ThisLove_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# MichaelJackson_BeatIt
#      > MichaelJackson_BeatIt Getting times and freqs...
#      > MichaelJackson_BeatIt Getting input/output pairs...
#     > using precomputed CQT for MichaelJackson_BeatIt_MIX.wav
#     Saved data for MarvinGaye_IHeardItThroughTheGrapevine_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# MightyMightyBosstones_WheredYouGo
#      > MightyMightyBosstones_WheredYouGo Getting times and freqs...
#      > MightyMightyBosstones_WheredYouGo Getting input/output pairs...
#     > using precomputed CQT for MightyMightyBosstones_WheredYouGo_MIX.wav
#     Saved data for MartinaMcbride_ThisOnesForTheGirls_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# MikeOldfield_Quicksilver
#     MikeOldfield_Quicksilver No bass data
# MileyCyrus_7Things
#     MileyCyrus_7Things No bass data
# MirandaCosgrove_HeadphonesOn
#      > MirandaCosgrove_HeadphonesOn Getting times and freqs...
#      > MirandaCosgrove_HeadphonesOn Getting input/output pairs...
#     > using precomputed CQT for MirandaCosgrove_HeadphonesOn_MIX.wav
#     Saved data for MarvinGaye_WhatsGoingOn_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Misfits_AstroZombies
#      > Misfits_AstroZombies Getting times and freqs...
#      > Misfits_AstroZombies Getting input/output pairs...
#     > using precomputed CQT for Misfits_AstroZombies_MIX.wav
#     Saved data for McFrontalot_LivinOnTheCornerOfDudeAndCatastrophe_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# ModestMouse_FloatOn
#      > ModestMouse_FloatOn Getting times and freqs...
#      > ModestMouse_FloatOn Getting input/output pairs...
#     > using precomputed CQT for ModestMouse_FloatOn_MIX.wav
#     Saved data for MightyMightyBosstones_WheredYouGo_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Muffs_KidsInAmerica
#      > Muffs_KidsInAmerica Getting times and freqs...
#      > Muffs_KidsInAmerica Getting input/output pairs...
#     > using precomputed CQT for Muffs_KidsInAmerica_MIX.wav
#     Saved data for Misfits_AstroZombies_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Muse_Hysteria
#     Muse_Hysteria No bass data
# TPain_Bartender
#     TPain_Bartender No bass data
# TalkingHeads_PsychoKiller
#      > TalkingHeads_PsychoKiller Getting times and freqs...
# [Parallel(n_jobs=-1)]: Done 277 tasks      | elapsed: 93.9min
#      > TalkingHeads_PsychoKiller Getting input/output pairs...
#     > using precomputed CQT for TalkingHeads_PsychoKiller_MIX.wav
#     Saved data for MirandaCosgrove_HeadphonesOn_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TaylorSwift_LoveStory
#      > TaylorSwift_LoveStory Getting times and freqs...
#      > TaylorSwift_LoveStory Getting input/output pairs...
#     > using precomputed CQT for TaylorSwift_LoveStory_MIX.wav
#     Saved data for MichaelJackson_BeatIt_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TaylorSwift_YouBelongWithMe
#      > TaylorSwift_YouBelongWithMe Getting times and freqs...
#      > TaylorSwift_YouBelongWithMe Getting input/output pairs...
#     > using precomputed CQT for TaylorSwift_YouBelongWithMe_MIX.wav
#     Saved data for LynyrdSkynyrd_FreeBird_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TearsForFears_EverybodyWantsToRuleTheWorld
#     TearsForFears_EverybodyWantsToRuleTheWorld No bass data
# Tesla_ModernDayCowboy
#     Tesla_ModernDayCowboy No bass data
# TheAllAmericanRejects_DirtyLittleSecret
#      > TheAllAmericanRejects_DirtyLittleSecret Getting times and freqs...
#      > TheAllAmericanRejects_DirtyLittleSecret Getting input/output pairs...
#     > using precomputed CQT for TheAllAmericanRejects_DirtyLittleSecret_MIX.wav
#     Saved data for ModestMouse_FloatOn_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TheAllmanBrothersBand_RamblinMan
#      > TheAllmanBrothersBand_RamblinMan Getting times and freqs...
#      > TheAllmanBrothersBand_RamblinMan Getting input/output pairs...
#     > using precomputed CQT for TheAllmanBrothersBand_RamblinMan_MIX.wav
#     Saved data for Muffs_KidsInAmerica_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TheBeatles_TwistAndShout
#      > TheBeatles_TwistAndShout Getting times and freqs...
# TheBeatles_Wait
#      > TheBeatles_Wait Getting times and freqs...
# TheBeatles_WhatGoesOn
#      > TheBeatles_WhatGoesOn Getting times and freqs...
# TheBeatles_WhenIm64
#      > TheBeatles_WhenIm64 Getting times and freqs...
# TheBeatles_WhileMyGuitarGentlyWeeps
#      > TheBeatles_WhileMyGuitarGentlyWeeps Getting times and freqs...
# TheBeatles_WithALittleHelpFromMyFriends
#      > TheBeatles_WithALittleHelpFromMyFriends Getting times and freqs...
# TheBeatles_WithinYouWithoutYou
#     TheBeatles_WithinYouWithoutYou No bass data
# TheBeatles_YellowSubmarine
#      > TheBeatles_YellowSubmarine Getting times and freqs...
# TheBeatles_YouWontSeeMe
#      > TheBeatles_YouWontSeeMe Getting times and freqs...
# TheBlackKeys_YourTouch
#     TheBlackKeys_YourTouch No bass data
# TheBravery_Believe
#     TheBravery_Believe No bass data
# TheBronx_FalseAlarm
#      > TheBronx_FalseAlarm Getting times and freqs...
#      > TheBronx_FalseAlarm Getting input/output pairs...
#     > using precomputed CQT for TheBronx_FalseAlarm_MIX.wav
#     Saved data for TaylorSwift_LoveStory_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TheBronx_SixDaysAWeek
#      > TheBronx_SixDaysAWeek Getting times and freqs...
#      > TheBronx_SixDaysAWeek Getting input/output pairs...
#     > using precomputed CQT for TheBronx_SixDaysAWeek_MIX.wav
#     Saved data for TaylorSwift_YouBelongWithMe_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TheKillers_SomebodyToldMe
#      > TheKillers_SomebodyToldMe Getting times and freqs...
#      > TheKillers_SomebodyToldMe Getting input/output pairs...
#     > using precomputed CQT for TheKillers_SomebodyToldMe_MIX.wav
#     Saved data for TalkingHeads_PsychoKiller_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TheKooks_Naive
#      > TheKooks_Naive Getting times and freqs...
#      > TheKooks_Naive Getting input/output pairs...
#     > using precomputed CQT for TheKooks_Naive_MIX.wav
#     Saved data for TheBronx_FalseAlarm_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TheLastGoodnight_PicturesOfYou
#      > TheLastGoodnight_PicturesOfYou Getting times and freqs...
#      > TheLastGoodnight_PicturesOfYou Getting input/output pairs...
#     > using precomputed CQT for TheLastGoodnight_PicturesOfYou_MIX.wav
#     Saved data for TheAllAmericanRejects_DirtyLittleSecret_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TheTurtles_HappyTogether
#      > TheTurtles_HappyTogether Getting times and freqs...
#      > TheTurtles_HappyTogether Getting input/output pairs...
#     > using precomputed CQT for TheTurtles_HappyTogether_MIX.wav
#     Saved data for TheKooks_Naive_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# ThinLizzy_TheBoysAreBackInTown
#      > ThinLizzy_TheBoysAreBackInTown Getting times and freqs...
#      > ThinLizzy_TheBoysAreBackInTown Getting input/output pairs...
#     > using precomputed CQT for ThinLizzy_TheBoysAreBackInTown_MIX.wav
#     Saved data for TheLastGoodnight_PicturesOfYou_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# ThirdEyeBlind_Jumper
#      > ThirdEyeBlind_Jumper Getting times and freqs...
#      > ThirdEyeBlind_Jumper Getting input/output pairs...
#     > using precomputed CQT for ThirdEyeBlind_Jumper_MIX.wav
#     Saved data for ThirdEyeBlind_Jumper_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# ThirdEyeBlind_NeverLetYouGo
#      > ThirdEyeBlind_NeverLetYouGo Getting times and freqs...
#      > ThirdEyeBlind_NeverLetYouGo Getting input/output pairs...
#     > using precomputed CQT for ThirdEyeBlind_NeverLetYouGo_MIX.wav
#     Saved data for TheBronx_SixDaysAWeek_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TomPettyAndTheHeartbreakers_IWontBackDown
#      > TomPettyAndTheHeartbreakers_IWontBackDown Getting times and freqs...
#      > TomPettyAndTheHeartbreakers_IWontBackDown Getting input/output pairs...
#     > using precomputed CQT for TomPettyAndTheHeartbreakers_IWontBackDown_MIX.wav
#     Saved data for TheKillers_SomebodyToldMe_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TomPetty_FreeFallin
#      > TomPetty_FreeFallin Getting times and freqs...
#      > TomPetty_FreeFallin Getting input/output pairs...
#     > using precomputed CQT for TomPetty_FreeFallin_MIX.wav
#     Saved data for TheAllmanBrothersBand_RamblinMan_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# Tonic_IfYouCouldOnlySee
#      > Tonic_IfYouCouldOnlySee Getting times and freqs...
#      > Tonic_IfYouCouldOnlySee Getting input/output pairs...
#     > using precomputed CQT for Tonic_IfYouCouldOnlySee_MIX.wav
#     Saved data for TheTurtles_HappyTogether_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# TvOnTheRadio_WolfLikeMe
#     TvOnTheRadio_WolfLikeMe No bass data
# VampireWeekend_Cousins
#      > VampireWeekend_Cousins Getting times and freqs...
#      > VampireWeekend_Cousins Getting input/output pairs...
#     > using precomputed CQT for VampireWeekend_Cousins_MIX.wav
#     Saved data for TomPettyAndTheHeartbreakers_IWontBackDown_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# VampireWeekend_Holiday
#      > VampireWeekend_Holiday Getting times and freqs...
#      > VampireWeekend_Holiday Getting input/output pairs...
#     > using precomputed CQT for VampireWeekend_Holiday_MIX.wav
#     Saved data for VampireWeekend_Cousins_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# VanHalen_Jump
#      > VanHalen_Jump Getting times and freqs...
# VanillaIce_IceIceBaby
#      > VanillaIce_IceIceBaby Getting times and freqs...
#      > VanillaIce_IceIceBaby Getting input/output pairs...
#     > using precomputed CQT for VanillaIce_IceIceBaby_MIX.wav
#     Saved data for ThinLizzy_TheBoysAreBackInTown_bass to /scratch/rmb456/multif0_ismir2017/training_data_with_blur/bass/
# VillagePeople_Ymca
#      > VillagePeople_Ymca Getting times and freqs...
#      > VillagePeople_Ymca Getting input/output pairs...
#     > using precomputed CQT for VillagePeople_Ymca_MIX.wav

# %%
# %run compute_training_data.py "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/vocal/" "vocal" -1 "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_incomplete/inputs" "--blur-labels"

# %%
data_dir = ("/scratch/rmb456/multif0_ismir2017/" +
    "training_data_with_blur/multif0_complete")

# %%
import medleydb as mdb
import glob
import shutil
import os

# %%
mtracks = list(mtracks)

# %%
new_dir = "/scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/bad_extras"

# %%
mtracks = mdb.load_all_multitracks(dataset_version=['EXTRA'])
good_count = 0
bad_count = 0

for mtrack in mtracks:
    bad_mtrack = False
    for stem in mtrack.stems.values():
        if stem.pitch_estimate_pyin is not None:

            if 'p' in stem.f0_type:
                bad_mtrack = True
                print(stem.instrument)
    if bad_mtrack:
        bad_count += 1
        print mtrack.track_id
    else:
        good_count += 1
        
        
    if bad_mtrack:
        flist = glob.glob(os.path.join(data_dir, "{}*".format(mtrack.track_id)))
        if len(flist) > 0:
            for f in flist:
                bname = os.path.basename(f)
                os.rename(f, os.path.join(new_dir, bname))

# %%
mtracks = mdb.load_all_multitracks(dataset_version=['V1'])
for mtrack in mtracks:
    if mtrack.has_melody:
        flist = glob.glob(os.path.join(data_dir, "{}*".format(mtrack.track_id)))
        if len(flist) > 0:
            for f in flist:
                print(f)
                os.remove(f)

# %%
rm /scratch/rmb456/multif0_ismir2017/training_data_with_blur/multif0_complete/*/TrevorAndTheSoundwaves_AloneAndSad_multif0_complete*.npy

# %%
x = 5
print(x)
