# %% [markdown]
# This notebook was used to compare different model architectures based on the test scores

# %%
import pandas as pd
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
experiment_folders = glob.glob("../experiment_output_submission/multif0_*exper*")
print(experiment_folders)
# Out:
# ['../experiment_output_submission/multif0_exper2', '../experiment_output_submission/multif0_exper12', '../experiment_output_submission/multif0_exper4_batchin', '../experiment_output_submission/multif0_exper9', '../experiment_output_submission/multif0_exper2_batchin', '../experiment_output_submission/multif0_exper15', '../experiment_output_submission/multif0_exper17', '../experiment_output_submission/multif0_exper7', '../experiment_output_submission/multif0_exper11_batchin_pitch', '../experiment_output_submission/multif0_exper14', '../experiment_output_submission/multif0_exper11_batchin_mf0incomplete', '../experiment_output_submission/multif0_exper11_batchin_mel2', '../experiment_output_submission/multif0_exper8', '../experiment_output_submission/multif0_exper10_batchin', '../experiment_output_submission/multif0_exper3', '../experiment_output_submission/multif0_exper16', '../experiment_output_submission/multif0_exper14_batchin', '../experiment_output_submission/multif0_exper12_batchin', '../experiment_output_submission/multif0_exper17_batchin', '../experiment_output_submission/multif0_exper11', '../experiment_output_submission/multif0_exper9_batchin', '../experiment_output_submission/multif0_exper3_batchin', '../experiment_output_submission/multif0_exper11_batchin_mel1', '../experiment_output_submission/multif0_exper6', '../experiment_output_submission/multif0_exper7_batchin', '../experiment_output_submission/multif0_exper8_batchin', '../experiment_output_submission/multif0_exper11_batchin_mel3', '../experiment_output_submission/multif0_exper4', '../experiment_output_submission/multif0_exper1', '../experiment_output_submission/multif0_exper16_batchin', '../experiment_output_submission/multif0_exper1_batchin', '../experiment_output_submission/multif0_exper10', '../experiment_output_submission/multif0_exper5', '../experiment_output_submission/multif0_exper15_batchin', '../experiment_output_submission/multif0_exper6_batchin', '../experiment_output_submission/multif0_exper13_batchin', '../experiment_output_submission/multif0_exper5_batchin', '../experiment_output_submission/multif0_exper13', '../experiment_output_submission/multif0_exper11_batchin']

# %%
def get_aggregate_df(dataset_fname):
    metrics = [
        'Precision', 'Recall','Accuracy', 'Substitution Error',
        'Miss Error', 'False Alarm Error', 'Total Error', 'Chroma Precision',
        'Chroma Recall', 'Chroma Accuracy', 'Chroma Substitution Error',
        'Chroma Miss Error', 'Chroma False Alarm Error', 'Chroma Total Error'
    ]

    scores_mean = {m: [] for m in metrics}
    scores_std = {m: [] for m in metrics}
    model_key = []
    data_frames = []
    
    experiment_folders = []
    for i in range(17):
        experiment_folders.append("../experiment_output_submission/multif0_exper{}".format(str(i+1)))
        experiment_folders.append("../experiment_output_submission/multif0_exper{}_batchin".format(str(i+1)))
    
    for folder in experiment_folders:
        dataset_scores = os.path.join(folder, dataset_fname)
        if os.path.exists(dataset_scores):
            model_key.append(folder)
            df = pd.read_csv(dataset_scores)
            for m in metrics:
                scores_mean[m].append(df.ix[1][m])
                scores_std[m].append(df.ix[2][m])
        else:
            model_key.append(folder)
            for m in metrics:
                scores_mean[m].append(0)
                scores_std[m].append(0)
    
    return scores_mean, scores_std, model_key

# %%
bach10_mean, bach10_std, bach10_models = get_aggregate_df("bach10_score_summary.csv")
mdb_mean, mdb_std, mdb_models = get_aggregate_df("mdb_test_score_summary.csv")
su_mean, su_std, su_models = get_aggregate_df("su_score_summary.csv")

# %%
m = 'Accuracy'

tick_colors = sns.color_palette('husl', 17)
formats = ['o', 'D']

plt.figure(figsize=(15, 10))
plt.title("Bach10")
plt.plot([0, 35], [0.758471, 0.758471], '--', color='b', label='Benetos')
plt.plot([0, 34], [0.681651, 0.681651], '--', color='g', label='Duan')
x_labs = []
for j, k in enumerate(bach10_models):
    fmt = formats[j % 2]
    if j % 2 == 0:
        color = tick_colors[j % 17]
    else:
        color = tick_colors[(j-1) % 17]
    plt.errorbar(j, bach10_mean[m][j], yerr=bach10_std[m][j], fmt=fmt, label=k, color=color)
    x_labs.append(k)
plt.errorbar(j+1, 0.681651, 0.026199, fmt='s', label='Duan', color='g')
plt.errorbar(j+2, 0.758471, 0.026418, fmt='s', label='Benetos', color='b')
plt.xticks(range(len(bach10_models)) + [34, 35], x_labs + ['DUAN', 'BENETOS'], rotation='vertical')
plt.ylabel(m)
plt.legend(ncol=2, bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.savefig("../paper-figs/all_results_Bach10.pdf", format='pdf')

plt.figure(figsize=(15, 10))
plt.title("MedleyDB -- Test")
plt.plot([0, 35], [0.297041, 0.297041], '--', color='b', label='Benetos')
plt.plot([0, 34], [0.234573, 0.234573], '--', color='g', label='Duan')
x_labs = []
for j, k in enumerate(mdb_models):
    fmt = formats[j % 2]
    if j % 2 == 0:
        color = tick_colors[j % 17]
    else:
        color = tick_colors[(j-1) % 17]
    plt.errorbar(j, mdb_mean[m][j], yerr=mdb_std[m][j], fmt=fmt, label=k, color=color)
    x_labs.append(k)
plt.errorbar(j+1, 0.234573, 0.079084, fmt='s', label='Duan', color='g')
plt.errorbar(j+2, 0.297041, 0.114145, fmt='s', label='Benetos', color='b')
    
plt.xticks(range(len(mdb_models)) + [34, 35], x_labs + ['DUAN', 'BENETOS'], rotation='vertical')
plt.ylabel(m)
plt.legend(ncol=2, bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.savefig("../paper-figs/all_results_mdbtest.pdf", format='pdf')


plt.figure(figsize=(15, 10))
plt.title("Su")
plt.plot([0, 35], [0.355545, 0.355545], '--', color='b', label='Benetos')
plt.plot([0, 34], [0.317448, 0.317448], '--', color='g', label='Duan')
x_labs = []
for j, k in enumerate(su_models):
    fmt = formats[j % 2]
    if j % 2 == 0:
        color = tick_colors[j % 17]
    else:
        color = tick_colors[(j-1) % 17]
    plt.errorbar(j, su_mean[m][j], yerr=su_std[m][j], fmt=fmt, label=k, color=color)
    x_labs.append(k)
plt.errorbar(j+1, 0.317448, 0.064461, fmt='s', label='Duan', color='g')
plt.errorbar(j+2, 0.355545, 0.051333, fmt='s', label='Benetos', color='b')

plt.xticks(range(len(su_models)) + [34, 35], x_labs + ['DUAN', 'BENETOS'], rotation='vertical')
plt.ylabel(m)
plt.legend(ncol=2, bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.savefig("../paper-figs/all_results_su.pdf", format='pdf')

# %%
bach10_mean, bach10_std, bach10_models = get_aggregate_df("bach10_score_summary.csv")
mdb_mean, mdb_std, mdb_models = get_aggregate_df("mdb_test_score_summary.csv")
su_mean, su_std, su_models = get_aggregate_df("su_score_summary.csv")

table = []
for b, s, m, key in zip(bach10_mean['Accuracy'], su_mean['Accuracy'], mdb_mean['Accuracy'], bach10_models):
    table.append([key, b, s, m])

aggregate_df = pd.DataFrame(table, columns=['model', 'Bach10', 'Su', 'MDB'])
aggregate_df
# Out:
#                                                 model    Bach10        Su  \
# 0      ../experiment_output_submission/multif0_exper1  0.609633  0.333036
# 1   ../experiment_output_submission/multif0_exper1...  0.644943  0.332760
# 2      ../experiment_output_submission/multif0_exper2  0.633181  0.345376
# 3   ../experiment_output_submission/multif0_exper2...  0.642781  0.336703
# 4      ../experiment_output_submission/multif0_exper3  0.631189  0.349644
# 5   ../experiment_output_submission/multif0_exper3...  0.677460  0.320827
# 6      ../experiment_output_submission/multif0_exper4  0.389948  0.343947
# 7   ../experiment_output_submission/multif0_exper4...  0.372435  0.365495
# 8      ../experiment_output_submission/multif0_exper5  0.451492  0.380291
# 9   ../experiment_output_submission/multif0_exper5...  0.437188  0.395811
# 10     ../experiment_output_submission/multif0_exper6  0.477666  0.387105
# 11  ../experiment_output_submission/multif0_exper6...  0.504418  0.376119
# 12     ../experiment_output_submission/multif0_exper7  0.444897  0.372262
# 13  ../experiment_output_submission/multif0_exper7...  0.414995  0.358779
# 14     ../experiment_output_submission/multif0_exper8  0.308967  0.346660
# 15  ../experiment_output_submission/multif0_exper8...  0.519227  0.407353
# 16     ../experiment_output_submission/multif0_exper9  0.443948  0.390275
# 17  ../experiment_output_submission/multif0_exper9...  0.538457  0.401773
# 18    ../experiment_output_submission/multif0_exper10  0.460450  0.349529
# 19  ../experiment_output_submission/multif0_exper1...  0.231764  0.267305
# 20    ../experiment_output_submission/multif0_exper11  0.263483  0.325919
# 21  ../experiment_output_submission/multif0_exper1...  0.556948  0.406154
# 22    ../experiment_output_submission/multif0_exper12  0.548573  0.416567
# 23  ../experiment_output_submission/multif0_exper1...  0.491834  0.380156
# 24    ../experiment_output_submission/multif0_exper13  0.448195  0.391728
# 25  ../experiment_output_submission/multif0_exper1...  0.531174  0.406826
# 26    ../experiment_output_submission/multif0_exper14  0.643257  0.301985
# 27  ../experiment_output_submission/multif0_exper1...  0.612054  0.342069
# 28    ../experiment_output_submission/multif0_exper15  0.632324  0.312781
# 29  ../experiment_output_submission/multif0_exper1...  0.653967  0.318981
# 30    ../experiment_output_submission/multif0_exper16  0.672673  0.318033
# 31    ../experiment_output_submission/multif0_exper17  0.637607  0.301670
# 32  ../experiment_output_submission/multif0_exper1...  0.630435  0.282053
#
#          MDB
# 0   0.385450
# 1   0.396667
# 2   0.386946
# 3   0.389766
# 4   0.324057
# 5   0.343322
# 6   0.489066
# 7   0.484351
# 8   0.452309
# 9   0.464837
# 10  0.484295
# 11  0.481106
# 12  0.471468
# 13  0.491013
# 14  0.471805
# 15  0.461706
# 16  0.481258
# 17  0.475363
# 18  0.485075
# 19  0.470942
# 20  0.482746
# 21  0.490294
# 22  0.466939
# 23  0.502208
# 24  0.471024
# 25  0.473345
# 26  0.340615
# 27  0.355769
# 28  0.367456
# 29  0.362015
# 30  0.349618
# 31  0.375963
# 32  0.384768
