# %%
cd ../deepsalience/
# Out:
# /scratch/rmb456/multif0/deepsalience

# %%
# %run compute_multitask_data.py "/scratch/rmb456/multif0_ismir2017/multitask_data/" "/scratch/rmb456/multif0_ismir2017/resynth_stems/" "/scratch/rmb456/multif0_ismir2017/replace_stems/"
# Out:
# Processing AClassicEducation_NightOwl...
#     Resynth annotations and mixing...
#     Fullmix annotations
# ...saved to /scratch/rmb456/multif0_ismir2017/multitask_data/AClassicEducation_NightOwl_training_pairs.json
#
# Processing AimeeNorwich_Child...
#     already done!
# Processing AimeeNorwich_Flying...
#     already done!
# Processing AlexanderRoss_GoodbyeBolero...
#     already done!
# Processing AlexanderRoss_VelvetCurtain...
#     already done!
# Processing AmarLal_Rest...
#     already done!
# Processing AmarLal_SpringDay1...
#     already done!
# Processing Auctioneer_OurFutureFaces...
#     already done!
# Processing AvaLuna_Waterduct...
#     Resynth annotations and mixing...
#     Fullmix annotations
# ...saved to /scratch/rmb456/multif0_ismir2017/multitask_data/AvaLuna_Waterduct_training_pairs.json
#
# Processing BigTroubles_Phantom...
#     Resynth annotations and mixing...
#     Fullmix annotations
# ...

# %%
# %run compute_multitask_training_pairs.py "/scratch/rmb456/multif0_ismir2017/multitask_data/" "/scratch/rmb456/multif0_ismir2017/multitask_data/XY_pairs/" -1
# Out:
#     > using precomputed CQT for TablaBreakbeatScience_Animoog_MIX_complete_resynth.wav
#     > using precomputed CQT for TleilaxEnsemble_Late_MIX.wav
#     > using precomputed CQT for BigTroubles_Phantom_MIX_complete_resynth.wav
#     > using precomputed CQT for Phoenix_LarkOnTheStrandDrummondCastle_MIX.wav
#     > using precomputed CQT for LizNelson_Coldwar_MIX_complete_noguitar.wav
#     > using precomputed CQT for TheAllmanBrothersBand_RamblinMan_MIX_complete_resynth.wav
#     > using precomputed CQT for MusicDelta_BebopJazz_MIX.wav
#     > using precomputed CQT for MatthewEntwistle_FairerHopes_MIX_complete_resynth.wav
#     > using precomputed CQT for TemperedElan_WiseOne_MIX.wav
#     > using precomputed CQT for TheBeatles_Wait_MIX.wav
#     > using precomputed CQT for MidnightBlue_StarsAreScreaming_MIX_complete_resynth.wav
#     > using precomputed CQT for MusicDelta_80sRock_MIX_complete_nosynth.wav
#     > using precomputed CQT for Phoenix_ElzicsFarewell_MIX.wav
# ...

# %%
import glob
import medleydb as mdb
import os

# %%
# mtracks = mdb.load_all_multitracks(dataset_version=['V1', 'V2', 'EXTRA'])
# for mtrack in mtracks:
#     if 'distorted electric guitar' in mtrack.stem_instruments:
#         print(mtrack.track_id)
#         fpaths = glob.glob(
#             "/scratch/rmb456/multif0_ismir2017/multitask_data/{}*".format(mtrack.track_id))
#         fpaths_XY = glob.glob(
#             "/scratch/rmb456/multif0_ismir2017/multitask_data/XY_pairs/{}*".format(mtrack.track_id)
#         )
#         print(fpaths)
#         print(fpaths_XY)
#         for fpath in fpaths + fpaths_XY:
#             os.remove(fpath)
# Out:
# AClassicEducation_NightOwl
# []
# []
# AvaLuna_Waterduct
# []
# []
# BigTroubles_Phantom
# []
# []
# Creepoid_OldTree
# []
# []
# EthanHein_GirlOnABridge
# []
# []
# FacesOnFilm_WaitingForGa
# []
# []
# FamilyBand_Again
# []
# []
# HopAlong_SisterCities
# []
# []
# Meaxic_TakeAStep
# []
# []
# Meaxic_YouListen
# []
# []
# MusicDelta_80sRock
# []
# []
# MusicDelta_Britpop
# []
# []
# MusicDelta_Grunge
# []
# []
# MusicDelta_Hendrix
# []
# []
# MusicDelta_Punk
# []
# []
# MusicDelta_Rockabilly
# []
# []
# MusicDelta_SpeedMetal
# []
# []
# MusicDelta_Zeppelin
# []
# []
# PurlingHiss_Lolita
# []
# []
# TablaBreakbeatScience_Animoog
# []
# []
# TheScarletBrand_LesFleursDuMal
# []
# []
# TheSoSoGlos_Emergency
# []
# []
# Cayetana_MissThing
# []
# []
# DeadMilkmen_PrisonersCinema
# []
# []
# FilthyBird_IdLikeToKnow
# []
# []
# FruitCathedral_KeepMeRunnin
# []
# []
# LittleTybee_TheAlchemist
# []
# []
# MidnightBlue_HuntingSeason
# []
# []
# MidnightBlue_StarsAreScreaming
# []
# []
# ...
