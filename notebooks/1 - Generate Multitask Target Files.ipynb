# %% [markdown]
# 1) Computes training audio (via mixing) and corresponding multitask labels as f0 sequences
#
# 2) Computes training pairs as matricies X (HCQT) --> Y (salience for each task)
#
# *Requires multitrack data from MedleyDB, a folder with pre-generated resynthesized stems, and optional stems to replace*

# %%
cd ../deepsalience/
# Out:
# /scratch/rmb456/multif0/deepsalience

# %%
mf0_data_path = '../training_data/mf0_data'
resynth_path = '../training_data/resynth_stems'
replace_path = '../training_data/replace_stems'
xy_pairs_path = '../training_data/XY_pairs'

# %%
# %run compute_multitask_data.py mf0_data_path resynth_path replace_path
# Out:
# Processing AClassicEducation_NightOwl...
#     already done!
# Processing AimeeNorwich_Child...
#     already done!
# Processing AimeeNorwich_Flying...
#     already done!
# Processing AlexanderRoss_GoodbyeBolero...
#     already done!
# Processing AlexanderRoss_VelvetCurtain...
#     already done!
# Processing AmarLal_Rest...
#     already done!
# Processing AmarLal_SpringDay1...
#     already done!
# Processing Auctioneer_OurFutureFaces...
#     already done!
# Processing AvaLuna_Waterduct...
#     already done!
# Processing BigTroubles_Phantom...
#     already done!
# Processing BrandonWebster_DontHearAThing...
#     already done!
# Processing BrandonWebster_YesSirICanFly...
#     already done!
# Processing CelestialShore_DieForUs...
#     already done!
# Processing ChrisJacoby_BoothShotLincoln...
#     already done!
# Processing ChrisJacoby_PigsFoot...
#     already done!
# Processing ClaraBerryAndWooldog_AirTraffic...
#     already done!
# ...

# %%
# %run compute_multitask_training_pairs.py mf0_data_path xy_pairs_path -1
# Out:
#     > computing CQT for BigTroubles_Phantom_MIX_complete_resynth.wav
#     > computing CQT for CelestialShore_DieForUs_MIX_complete_noguitar.wav
#     > computing CQT for MusicDelta_Rock_MIX_complete_nosynth.wav
#     > computing CQT for MusicDelta_BebopJazz_MIX.wav
#     > computing CQT for TheAllmanBrothersBand_RamblinMan_MIX_complete_resynth.wav
#     > computing CQT for TheBeatles_Wait_MIX.wav
#     > computing CQT for Sweat_Sn1572_MIX.wav
#     > computing CQT for EthanHein_GirlOnABridge_MIX_complete_nosynth.wav
#     > computing CQT for Phoenix_ElzicsFarewell_MIX.wav
#     > computing CQT for TleilaxEnsemble_Late_MIX.wav
#     > computing CQT for StevenClark_Bounty_MIX_complete_resynth.wav
#     > computing CQT for MusicDelta_80sRock_MIX_complete_nosynth.wav
#     > computing CQT for MatthewEntwistle_FairerHopes_MIX_complete_resynth.wav
#     > computing CQT for TablaBreakbeatScience_Animoog_MIX_complete_resynth.wav
# ...
